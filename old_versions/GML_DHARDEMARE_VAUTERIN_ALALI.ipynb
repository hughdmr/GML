# %% [markdown]
# # Comparative Analysis of Twitter Ego Networks
#
# This notebook performs a comparative analysis of ego networks with fewer graphs and more comparative tables (saved as CSVs).

# %%
# Import Required Libraries
import pandas as pd
import networkx as nx
import numpy as np
import matplotlib
matplotlib.use('Agg')  # non-interactive backend
import matplotlib.pyplot as plt
import seaborn as sns
import os
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Set plotting style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

# %% [markdown]
# ## 1. Load All Twitter Ego Networks
#
# Identify ego networks and load components.

# %%
# Define the path to the Twitter ego networks
twitter_path = "twitter_ego/twitter"

# Output folder for summary tables/plots
summary_dir = Path(twitter_path) / "summary_tables"
summary_dir.mkdir(parents=True, exist_ok=True)

# Find all unique node IDs by looking for .edges files
ego_network_ids = []
if os.path.exists(twitter_path):
    for file in os.listdir(twitter_path):
        if file.endswith('.edges'):
            node_id = file.replace('.edges', '')
            ego_network_ids.append(node_id)
    ego_network_ids.sort()
    print(f"Found {len(ego_network_ids)} ego networks")
else:
    print(f"Directory {twitter_path} not found!")
# Out:
# Found 973 ego networks

# %%
# Function to load an ego network
def load_ego_network(node_id, twitter_path="twitter_ego/twitter"):
    data = {}
    edges_file = f"{twitter_path}/{node_id}.edges"
    if os.path.exists(edges_file):
        try:
            data['edges'] = pd.read_csv(edges_file, sep=r"\s+", header=None, names=['source','target'], engine='python')
        except Exception:
            data['edges'] = pd.read_csv(edges_file, sep=' ', header=None, names=['source','target'])
    else:
        data['edges'] = pd.DataFrame(columns=['source','target'])
    
    feat_file = f"{twitter_path}/{node_id}.feat"
    if os.path.exists(feat_file):
        data['feat'] = pd.read_csv(feat_file, sep=r"\s+", header=None, engine='python')
    else:
        data['feat'] = None
    
    egofeat_file = f"{twitter_path}/{node_id}.egofeat"
    if os.path.exists(egofeat_file):
        data['egofeat'] = pd.read_csv(egofeat_file, sep=r"\s+", header=None, engine='python')
    else:
        data['egofeat'] = None
    
    circles_file = f"{twitter_path}/{node_id}.circles"
    circles = {}
    if os.path.exists(circles_file):
        with open(circles_file, 'r') as f:
            for line in f:
                parts = line.strip().split()
                if not parts:
                    continue
                circles[parts[0]] = parts[1:] if len(parts) > 1 else []
    data['circles'] = circles
    return data

# Load all ego networks (small log)
all_networks = {}
for node_id in ego_network_ids:
    all_networks[node_id] = load_ego_network(node_id, twitter_path=twitter_path)
    print(f"Loaded network {node_id}: {len(all_networks[node_id]['edges'])} edges, {len(all_networks[node_id]['circles'])} circles")
# Out:
# Loaded network 100318079: 8354 edges, 4 circles
# Loaded network 10146102: 951 edges, 1 circles
# Loaded network 101859065: 208 edges, 4 circles
# Loaded network 101903164: 51 edges, 2 circles
# Loaded network 102765423: 1070 edges, 3 circles
# Loaded network 102903198: 4925 edges, 1 circles
# Loaded network 103431502: 473 edges, 2 circles
# Loaded network 103865085: 2484 edges, 2 circles
# Loaded network 103991905: 615 edges, 2 circles
# Loaded network 104324908: 77 edges, 2 circles
# Loaded network 104615636: 506 edges, 3 circles
# Loaded network 1046661: 1642 edges, 7 circles
# Loaded network 104991493: 2419 edges, 5 circles
# Loaded network 105150583: 4795 edges, 5 circles
# Loaded network 105398724: 166 edges, 2 circles
# Loaded network 105918870: 2849 edges, 7 circles
# Loaded network 107172099: 285 edges, 2 circles
# Loaded network 107418464: 1739 edges, 2 circles
# Loaded network 107511013: 294 edges, 0 circles
# Loaded network 107512718: 2322 edges, 17 circles
# Loaded network 107516840: 7160 edges, 5 circles
# Loaded network 10798802: 1888 edges, 4 circles
# Loaded network 108159877: 2134 edges, 2 circles
# Loaded network 108205076: 4339 edges, 3 circles
# Loaded network 10985532: 920 edges, 10 circles
# Loaded network 11027262: 3499 edges, 3 circles
# Loaded network 110536616: 429 edges, 2 circles
# Loaded network 110755733: 712 edges, 1 circles
# Loaded network 111045742: 3380 edges, 2 circles
# Loaded network 11136132: 1364 edges, 0 circles
# Loaded network 111374622: 3632 edges, 3 circles
# Loaded network 112628165: 3106 edges, 2 circles
# Loaded network 113196940: 1013 edges, 5 circles
# Loaded network 11348282: 5001 edges, 8 circles
# Loaded network 11348722: 3823 edges, 3 circles
# Loaded network 113509970: 1193 edges, 6 circles
# Loaded network 114115460: 1567 edges, 4 circles
# Loaded network 114885421: 3731 edges, 14 circles
# Loaded network 115221382: 2668 edges, 18 circles
# Loaded network 115911638: 4067 edges, 5 circles
# Loaded network 116388817: 209 edges, 2 circles
# Loaded network 116798290: 4069 edges, 1 circles
# Loaded network 116808228: 56 edges, 2 circles
# Loaded network 11681802: 971 edges, 3 circles
# Loaded network 117029850: 557 edges, 2 circles
# Loaded network 117671022: 3384 edges, 2 circles
# Loaded network 117800618: 1323 edges, 32 circles
# Loaded network 117809922: 1227 edges, 2 circles
# Loaded network 11784842: 656 edges, 2 circles
# Loaded network 11828432: 2203 edges, 3 circles
# Loaded network 11928542: 326 edges, 2 circles
# Loaded network 119897041: 569 edges, 2 circles
# Loaded network 120157205: 358 edges, 1 circles
# Loaded network 120459837: 6195 edges, 2 circles
# Loaded network 120679977: 622 edges, 2 circles
# Loaded network 12069912: 4463 edges, 3 circles
# Loaded network 120971873: 2669 edges, 1 circles
# Loaded network 121202578: 4026 edges, 4 circles
# Loaded network 121258930: 245 edges, 2 circles
# Loaded network 12152402: 1353 edges, 3 circles
# Loaded network 121569946: 1465 edges, 3 circles
# Loaded network 121685268: 1982 edges, 2 circles
# Loaded network 122216533: 335 edges, 0 circles
# Loaded network 123287376: 4973 edges, 3 circles
# Loaded network 123684709: 3790 edges, 3 circles
# Loaded network 1239671: 934 edges, 2 circles
# Loaded network 12415722: 2114 edges, 2 circles
# Loaded network 124296976: 1849 edges, 7 circles
# Loaded network 124474025: 5191 edges, 2 circles
# Loaded network 125098615: 811 edges, 5 circles
# Loaded network 12570812: 1560 edges, 3 circles
# Loaded network 126067398: 51 edges, 2 circles
# Loaded network 1271901: 4416 edges, 0 circles
# Loaded network 12771872: 1676 edges, 6 circles
# Loaded network 127912925: 836 edges, 4 circles
# Loaded network 128135741: 450 edges, 3 circles
# Loaded network 12831: 2478 edges, 1 circles
# Loaded network 129093262: 4207 edges, 1 circles
# Loaded network 129984134: 6023 edges, 2 circles
# Loaded network 130734452: 91 edges, 6 circles
# Loaded network 13179562: 3507 edges, 2 circles
# Loaded network 13212502: 2262 edges, 2 circles
# Loaded network 132519763: 1646 edges, 6 circles
# Loaded network 13274152: 1189 edges, 8 circles
# Loaded network 13275962: 4106 edges, 9 circles
# Loaded network 13317162: 2184 edges, 3 circles
# Loaded network 133663120: 3741 edges, 2 circles
# Loaded network 134208594: 2639 edges, 12 circles
# Loaded network 13460312: 561 edges, 1 circles
# Loaded network 134943586: 8041 edges, 11 circles
# Loaded network 135397331: 3101 edges, 4 circles
# Loaded network 135605269: 1582 edges, 8 circles
# Loaded network 135704499: 513 edges, 4 circles
# Loaded network 135895585: 716 edges, 2 circles
# Loaded network 136341512: 348 edges, 2 circles
# Loaded network 13649212: 2232 edges, 2 circles
# Loaded network 1367531: 8120 edges, 4 circles
# Loaded network 137046366: 2989 edges, 2 circles
# Loaded network 13747362: 672 edges, 7 circles
# Loaded network 137527381: 455 edges, 2 circles
# Loaded network 13809612: 3324 edges, 4 circles
# Loaded network 13811562: 7728 edges, 5 circles
# Loaded network 13837812: 5132 edges, 2 circles
# Loaded network 13872872: 3529 edges, 1 circles
# Loaded network 14045302: 1973 edges, 2 circles
# Loaded network 14058831: 2456 edges, 3 circles
# Loaded network 14060856: 2642 edges, 8 circles
# Loaded network 14077024: 4227 edges, 4 circles
# Loaded network 14120151: 4158 edges, 2 circles
# Loaded network 14120253: 1038 edges, 4 circles
# Loaded network 14129601: 1149 edges, 11 circles
# Loaded network 141341662: 1052 edges, 5 circles
# Loaded network 14134942: 4767 edges, 2 circles
# Loaded network 14147754: 909 edges, 2 circles
# Loaded network 141488457: 2498 edges, 3 circles
# Loaded network 14150874: 224 edges, 2 circles
# Loaded network 14191254: 1433 edges, 3 circles
# Loaded network 14199378: 4577 edges, 10 circles
# Loaded network 14203895: 3640 edges, 2 circles
# Loaded network 1422311: 4481 edges, 1 circles
# Loaded network 14256927: 1831 edges, 2 circles
# Loaded network 14313005: 2704 edges, 3 circles
# Loaded network 143172151: 1186 edges, 2 circles
# Loaded network 14327149: 111 edges, 1 circles
# Loaded network 14332288: 1642 edges, 2 circles
# Loaded network 143344048: 444 edges, 1 circles
# Loaded network 14338082: 3237 edges, 18 circles
# Loaded network 14353392: 4750 edges, 2 circles
# Loaded network 1435461: 8037 edges, 2 circles
# Loaded network 14365883: 1378 edges, 2 circles
# Loaded network 143661263: 3045 edges, 2 circles
# Loaded network 14371740: 2827 edges, 3 circles
# Loaded network 14372486: 1467 edges, 6 circles
# Loaded network 14372763: 1209 edges, 2 circles
# Loaded network 14404235: 557 edges, 2 circles
# Loaded network 144211337: 2515 edges, 2 circles
# Loaded network 14422788: 2224 edges, 3 circles
# Loaded network 14426892: 3641 edges, 4 circles
# Loaded network 144723379: 2547 edges, 18 circles
# Loaded network 14505838: 280 edges, 2 circles
# Loaded network 14521330: 476 edges, 1 circles
# Loaded network 14528221: 1606 edges, 5 circles
# Loaded network 14550962: 1505 edges, 2 circles
# Loaded network 14555534: 698 edges, 4 circles
# Loaded network 145573135: 1585 edges, 3 circles
# Loaded network 14618160: 583 edges, 3 circles
# Loaded network 14630490: 1538 edges, 1 circles
# Loaded network 14677919: 6687 edges, 3 circles
# Loaded network 14711172: 8 edges, 0 circles
# Loaded network 14719129: 456 edges, 4 circles
# Loaded network 14755105: 2293 edges, 2 circles
# Loaded network 14791232: 4168 edges, 4 circles
# Loaded network 14794851: 2083 edges, 2 circles
# Loaded network 14807093: 3522 edges, 1 circles
# Loaded network 14827526: 276 edges, 1 circles
# Loaded network 14836915: 5638 edges, 6 circles
# Loaded network 14838506: 774 edges, 3 circles
# Loaded network 14840869: 811 edges, 5 circles
# Loaded network 14843763: 769 edges, 2 circles
# Loaded network 14848513: 2616 edges, 4 circles
# Loaded network 14849487: 1693 edges, 0 circles
# Loaded network 148519842: 2674 edges, 1 circles
# Loaded network 14869783: 1124 edges, 3 circles
# Loaded network 14893314: 1298 edges, 2 circles
# Loaded network 14917050: 977 edges, 2 circles
# Loaded network 14922225: 3017 edges, 6 circles
# Loaded network 14936377: 667 edges, 3 circles
# Loaded network 14957252: 4029 edges, 5 circles
# Loaded network 14984096: 657 edges, 9 circles
# Loaded network 15001424: 217 edges, 2 circles
# Loaded network 15012486: 8638 edges, 12 circles
# Loaded network 150402542: 1088 edges, 1 circles
# Loaded network 15053535: 26 edges, 3 circles
# Loaded network 15070932: 4383 edges, 2 circles
# Loaded network 15099384: 894 edges, 3 circles
# Loaded network 151175266: 3486 edges, 3 circles
# Loaded network 151246522: 442 edges, 2 circles
# Loaded network 15129912: 692 edges, 3 circles
# Loaded network 151495845: 8972 edges, 3 circles
# Loaded network 15164892: 1308 edges, 2 circles
# Loaded network 152062126: 2087 edges, 3 circles
# Loaded network 15208246: 7892 edges, 3 circles
# Loaded network 152388029: 2295 edges, 3 circles
# Loaded network 152435436: 3348 edges, 5 circles
# Loaded network 15292446: 7286 edges, 3 circles
# Loaded network 153245741: 1665 edges, 3 circles
# Loaded network 15329577: 4251 edges, 2 circles
# Loaded network 15331855: 1566 edges, 2 circles
# Loaded network 15335809: 5858 edges, 5 circles
# Loaded network 15347317: 1731 edges, 4 circles
# Loaded network 15419775: 996 edges, 3 circles
# Loaded network 15420650: 815 edges, 2 circles
# Loaded network 15445811: 273 edges, 0 circles
# Loaded network 154648125: 416 edges, 2 circles
# Loaded network 154701532: 4616 edges, 2 circles
# Loaded network 15473958: 3612 edges, 3 circles
# Loaded network 15477120: 3871 edges, 3 circles
# Loaded network 15481789: 2854 edges, 4 circles
# Loaded network 1548841: 3155 edges, 4 circles
# Loaded network 15507297: 5541 edges, 2 circles
# Loaded network 15527013: 1092 edges, 2 circles
# Loaded network 15533771: 380 edges, 3 circles
# Loaded network 155661154: 6584 edges, 24 circles
# Loaded network 155689319: 3666 edges, 1 circles
# Loaded network 15589323: 176 edges, 2 circles
# Loaded network 155976326: 2261 edges, 4 circles
# Loaded network 15642031: 354 edges, 2 circles
# Loaded network 15647676: 4294 edges, 3 circles
# Loaded network 15665127: 2222 edges, 1 circles
# Loaded network 15706128: 1275 edges, 3 circles
# Loaded network 15741636: 922 edges, 3 circles
# Loaded network 157488488: 105 edges, 1 circles
# Loaded network 15797184: 138 edges, 4 circles
# Loaded network 158414847: 1338 edges, 3 circles
# Loaded network 158419434: 7201 edges, 1 circles
# Loaded network 15849055: 4182 edges, 3 circles
# Loaded network 15859268: 216 edges, 2 circles
# Loaded network 15864197: 1054 edges, 5 circles
# Loaded network 158874150: 3372 edges, 2 circles
# Loaded network 15924858: 39 edges, 0 circles
# Loaded network 15938936: 4276 edges, 2 circles
# Loaded network 15944663: 3321 edges, 4 circles
# Loaded network 15947217: 458 edges, 3 circles
# Loaded network 159588456: 4825 edges, 5 circles
# Loaded network 159629146: 4854 edges, 3 circles
# Loaded network 15977848: 1889 edges, 2 circles
# Loaded network 15989218: 4359 edges, 2 circles
# Loaded network 160237722: 7359 edges, 14 circles
# Loaded network 16027078: 1108 edges, 3 circles
# Loaded network 160839015: 791 edges, 6 circles
# Loaded network 1608991: 4569 edges, 12 circles
# Loaded network 16105942: 594 edges, 3 circles
# Loaded network 16183380: 5467 edges, 12 circles
# Loaded network 16193542: 1212 edges, 1 circles
# Loaded network 16212913: 1119 edges, 2 circles
# Loaded network 16234125: 1034 edges, 2 circles
# Loaded network 16247469: 4780 edges, 2 circles
# Loaded network 16263665: 1054 edges, 1 circles
# Loaded network 16279105: 731 edges, 4 circles
# Loaded network 16285517: 1892 edges, 2 circles
# Loaded network 16297193: 111 edges, 3 circles
# Loaded network 16305227: 823 edges, 3 circles
# Loaded network 163374693: 1749 edges, 2 circles
# Loaded network 163491360: 3393 edges, 3 circles
# Loaded network 163629705: 2267 edges, 10 circles
# Loaded network 163674521: 5286 edges, 5 circles
# Loaded network 16421962: 307 edges, 13 circles
# Loaded network 16437633: 269 edges, 0 circles
# Loaded network 16465113: 2245 edges, 0 circles
# Loaded network 16476088: 350 edges, 2 circles
# Loaded network 16505296: 417 edges, 2 circles
# Loaded network 165580617: 719 edges, 2 circles
# Loaded network 165598423: 3999 edges, 16 circles
# Loaded network 165786567: 2394 edges, 4 circles
# Loaded network 16591188: 1331 edges, 3 circles
# Loaded network 16606585: 1146 edges, 2 circles
# Loaded network 16610683: 554 edges, 3 circles
# Loaded network 16613128: 2418 edges, 0 circles
# Loaded network 16616109: 5508 edges, 1 circles
# Loaded network 166214735: 6691 edges, 19 circles
# Loaded network 166252256: 1412 edges, 2 circles
# Loaded network 16652550: 1637 edges, 5 circles
# Loaded network 16674149: 63 edges, 2 circles
# Loaded network 16685316: 1309 edges, 2 circles
# Loaded network 16726878: 2071 edges, 1 circles
# Loaded network 16734718: 2693 edges, 3 circles
# Loaded network 16790036: 2927 edges, 4 circles
# Loaded network 167901620: 325 edges, 1 circles
# Loaded network 16809036: 4894 edges, 8 circles
# Loaded network 168224294: 4552 edges, 19 circles
# Loaded network 16824073: 1519 edges, 0 circles
# Loaded network 16834201: 529 edges, 7 circles
# Loaded network 16840742: 1104 edges, 0 circles
# Loaded network 168537920: 1132 edges, 3 circles
# Loaded network 16869298: 2118 edges, 2 circles
# Loaded network 16878507: 2196 edges, 3 circles
# Loaded network 169216507: 6403 edges, 3 circles
# Loaded network 169780164: 4166 edges, 4 circles
# Loaded network 16987303: 13538 edges, 3 circles
# Loaded network 170167167: 2399 edges, 2 circles
# Loaded network 17022544: 651 edges, 2 circles
# Loaded network 17045060: 6143 edges, 4 circles
# Loaded network 170729553: 7990 edges, 6 circles
# Loaded network 17111909: 4713 edges, 2 circles
# Loaded network 171202083: 4901 edges, 2 circles
# Loaded network 17135931: 522 edges, 2 circles
# Loaded network 17137927: 1764 edges, 3 circles
# Loaded network 171536167: 245 edges, 17 circles
# Loaded network 17384099: 3134 edges, 1 circles
# Loaded network 17396702: 5063 edges, 2 circles
# Loaded network 17403755: 1312 edges, 4 circles
# Loaded network 17421011: 52 edges, 2 circles
# Loaded network 174285878: 4045 edges, 13 circles
# Loaded network 17503591: 1920 edges, 4 circles
# Loaded network 175529494: 1570 edges, 1 circles
# Loaded network 175553601: 8888 edges, 64 circles
# Loaded network 17561785: 2188 edges, 5 circles
# Loaded network 17600223: 1870 edges, 3 circles
# Loaded network 17602896: 2974 edges, 2 circles
# Loaded network 17627996: 283 edges, 3 circles
# Loaded network 176310143: 5150 edges, 8 circles
# Loaded network 17636894: 568 edges, 6 circles
# Loaded network 17658786: 6981 edges, 6 circles
# Loaded network 176589903: 301 edges, 2 circles
# Loaded network 176872879: 248 edges, 3 circles
# Loaded network 176936249: 50 edges, 1 circles
# Loaded network 17714569: 2868 edges, 6 circles
# Loaded network 17723880: 1891 edges, 3 circles
# Loaded network 1775731: 567 edges, 3 circles
# Loaded network 17767841: 967 edges, 7 circles
# Loaded network 17770689: 400 edges, 9 circles
# Loaded network 17787399: 1546 edges, 2 circles
# Loaded network 17797990: 5132 edges, 1 circles
# Loaded network 17822419: 3018 edges, 1 circles
# Loaded network 17866414: 6904 edges, 2 circles
# Loaded network 17874544: 107 edges, 2 circles
# Loaded network 179065820: 819 edges, 3 circles
# Loaded network 17912917: 523 edges, 2 circles
# Loaded network 179138862: 1832 edges, 21 circles
# Loaded network 17918629: 2647 edges, 3 circles
# Loaded network 17922109: 4825 edges, 3 circles
# Loaded network 180540375: 1413 edges, 43 circles
# Loaded network 18068719: 1937 edges, 2 circles
# Loaded network 18069824: 1372 edges, 2 circles
# Loaded network 18119683: 4647 edges, 3 circles
# Loaded network 18135029: 759 edges, 1 circles
# Loaded network 18191231: 2295 edges, 2 circles
# Loaded network 18201401: 461 edges, 2 circles
# Loaded network 18226205: 4721 edges, 3 circles
# Loaded network 18252740: 4104 edges, 5 circles
# Loaded network 182609394: 272 edges, 2 circles
# Loaded network 18270489: 693 edges, 13 circles
# Loaded network 18278524: 2840 edges, 2 circles
# Loaded network 18338485: 2842 edges, 1 circles
# Loaded network 18374320: 2693 edges, 2 circles
# Loaded network 183786731: 4657 edges, 2 circles
# Loaded network 184391654: 3073 edges, 2 circles
# Loaded network 184594566: 5721 edges, 3 circles
# Loaded network 18470775: 427 edges, 4 circles
# Loaded network 18472735: 995 edges, 6 circles
# Loaded network 184755890: 572 edges, 2 circles
# Loaded network 18481292: 1732 edges, 1 circles
# Loaded network 18483115: 540 edges, 2 circles
# Loaded network 18486243: 3042 edges, 4 circles
# Loaded network 18486881: 2146 edges, 6 circles
# Loaded network 18496986: 1561 edges, 3 circles
# Loaded network 18534908: 3304 edges, 5 circles
# Loaded network 185512077: 3408 edges, 2 circles
# Loaded network 18558612: 296 edges, 1 circles
# Loaded network 18571832: 788 edges, 2 circles
# Loaded network 18594420: 1596 edges, 5 circles
# Loaded network 18630326: 4853 edges, 6 circles
# Loaded network 186354564: 1128 edges, 5 circles
# Loaded network 18665800: 5100 edges, 6 circles
# Loaded network 18681592: 71 edges, 1 circles
# Loaded network 18687625: 450 edges, 5 circles
# Loaded network 18690700: 364 edges, 2 circles
# Loaded network 186909156: 6745 edges, 21 circles
# Loaded network 18718580: 2737 edges, 2 circles
# Loaded network 18731347: 4720 edges, 1 circles
# Loaded network 18734310: 4319 edges, 6 circles
# Loaded network 187569483: 3678 edges, 21 circles
# Loaded network 187744415: 9169 edges, 8 circles
# Loaded network 187773078: 3787 edges, 12 circles
# Loaded network 18788502: 2331 edges, 10 circles
# Loaded network 188102842: 5023 edges, 19 circles
# Loaded network 18836167: 2179 edges, 3 circles
# Loaded network 18846990: 2524 edges, 2 circles
# Loaded network 18886852: 5293 edges, 4 circles
# Loaded network 18895362: 2207 edges, 6 circles
# Loaded network 189111957: 3195 edges, 2 circles
# Loaded network 18917716: 356 edges, 1 circles
# Loaded network 18923866: 2903 edges, 2 circles
# Loaded network 189253902: 2291 edges, 5 circles
# Loaded network 18951737: 3257 edges, 11 circles
# Loaded network 18957524: 1522 edges, 13 circles
# Loaded network 189592841: 505 edges, 8 circles
# Loaded network 189875309: 5656 edges, 6 circles
# Loaded network 18988524: 157 edges, 7 circles
# Loaded network 18996905: 750 edges, 2 circles
# Loaded network 190138306: 2815 edges, 4 circles
# Loaded network 19064433: 4208 edges, 6 circles
# Loaded network 190696559: 1997 edges, 5 circles
# Loaded network 19110632: 5749 edges, 2 circles
# Loaded network 19136295: 2050 edges, 3 circles
# Loaded network 191896931: 589 edges, 3 circles
# Loaded network 191916463: 474 edges, 6 circles
# Loaded network 191924526: 1440 edges, 2 circles
# Loaded network 19208450: 2747 edges, 2 circles
# Loaded network 19213083: 1218 edges, 3 circles
# Loaded network 19225156: 441 edges, 1 circles
# Loaded network 19283723: 532 edges, 2 circles
# Loaded network 19299909: 956 edges, 2 circles
# Loaded network 19380307: 1172 edges, 3 circles
# Loaded network 19454519: 841 edges, 0 circles
# Loaded network 19492215: 3877 edges, 7 circles
# Loaded network 195475105: 8124 edges, 17 circles
# Loaded network 19563357: 3193 edges, 3 circles
# Loaded network 19658936: 2401 edges, 6 circles
# Loaded network 19668026: 2560 edges, 7 circles
# Loaded network 196926575: 1480 edges, 5 circles
# Loaded network 19725644: 393 edges, 6 circles
# Loaded network 197577781: 2631 edges, 1 circles
# Loaded network 197602850: 2206 edges, 2 circles
# Loaded network 19760380: 2213 edges, 1 circles
# Loaded network 197731654: 138 edges, 2 circles
# Loaded network 197903282: 6838 edges, 6 circles
# Loaded network 198327282: 4569 edges, 8 circles
# Loaded network 198370650: 264 edges, 3 circles
# Loaded network 198628427: 779 edges, 4 circles
# Loaded network 198941747: 8166 edges, 4 circles
# Loaded network 19898730: 2243 edges, 4 circles
# Loaded network 199039532: 4237 edges, 4 circles
# Loaded network 19933035: 1632 edges, 3 circles
# Loaded network 19948202: 5963 edges, 3 circles
# Loaded network 199483163: 1028 edges, 3 circles
# Loaded network 19976791: 216 edges, 2 circles
# Loaded network 200214366: 9451 edges, 12 circles
# Loaded network 200494218: 3858 edges, 2 circles
# Loaded network 20060293: 7542 edges, 2 circles
# Loaded network 20119746: 208 edges, 1 circles
# Loaded network 20179628: 2541 edges, 0 circles
# Loaded network 202114894: 5486 edges, 5 circles
# Loaded network 202195505: 7909 edges, 10 circles
# Loaded network 202346485: 816 edges, 2 circles
# Loaded network 2029971: 2830 edges, 7 circles
# Loaded network 20319646: 2669 edges, 2 circles
# Loaded network 20347014: 4712 edges, 5 circles
# Loaded network 203868162: 648 edges, 3 circles
# Loaded network 204145356: 1672 edges, 6 circles
# Loaded network 20436059: 3867 edges, 7 circles
# Loaded network 20446839: 546 edges, 2 circles
# Loaded network 204646586: 1806 edges, 2 circles
# Loaded network 20495756: 1997 edges, 2 circles
# Loaded network 20561154: 2388 edges, 3 circles
# Loaded network 20689206: 5926 edges, 5 circles
# Loaded network 206923844: 8896 edges, 3 circles
# Loaded network 20758393: 921 edges, 2 circles
# Loaded network 207594668: 223 edges, 1 circles
# Loaded network 207936757: 412 edges, 2 circles
# Loaded network 20950208: 931 edges, 3 circles
# Loaded network 2097571: 9407 edges, 15 circles
# Loaded network 20999409: 849 edges, 4 circles
# Loaded network 21028234: 344 edges, 8 circles
# Loaded network 21061498: 2515 edges, 2 circles
# Loaded network 21077642: 316 edges, 1 circles
# Loaded network 21094279: 4059 edges, 2 circles
# Loaded network 21132431: 585 edges, 10 circles
# Loaded network 211547273: 5198 edges, 2 circles
# Loaded network 211933541: 3775 edges, 4 circles
# Loaded network 21222922: 245 edges, 6 circles
# Loaded network 212642904: 1848 edges, 4 circles
# Loaded network 212718048: 414 edges, 0 circles
# Loaded network 21318259: 1068 edges, 2 circles
# Loaded network 21337501: 195 edges, 1 circles
# Loaded network 21339164: 1656 edges, 4 circles
# Loaded network 21363077: 2061 edges, 5 circles
# Loaded network 21364753: 732 edges, 2 circles
# Loaded network 21391704: 2027 edges, 2 circles
# Loaded network 21415375: 4687 edges, 2 circles
# Loaded network 21420959: 1787 edges, 2 circles
# Loaded network 21437537: 3994 edges, 3 circles
# Loaded network 215328630: 33 edges, 0 circles
# Loaded network 21578499: 2512 edges, 11 circles
# Loaded network 215824411: 40 edges, 1 circles
# Loaded network 21648994: 1026 edges, 4 circles
# Loaded network 216843160: 7155 edges, 14 circles
# Loaded network 21731779: 64 edges, 5 circles
# Loaded network 21735280: 1933 edges, 1 circles
# Loaded network 217796457: 12105 edges, 1 circles
# Loaded network 21816783: 271 edges, 2 circles
# Loaded network 219365298: 1031 edges, 3 circles
# Loaded network 22106463: 1815 edges, 13 circles
# Loaded network 22121627: 1923 edges, 7 circles
# Loaded network 222090651: 3581 edges, 2 circles
# Loaded network 22252971: 34 edges, 4 circles
# Loaded network 224581852: 4738 edges, 0 circles
# Loaded network 225302763: 1512 edges, 2 circles
# Loaded network 2257971: 435 edges, 2 circles
# Loaded network 22745706: 867 edges, 5 circles
# Loaded network 22751884: 488 edges, 6 circles
# Loaded network 227650565: 5101 edges, 6 circles
# Loaded network 227785045: 408 edges, 10 circles
# Loaded network 228270980: 4032 edges, 4 circles
# Loaded network 22863638: 2436 edges, 5 circles
# Loaded network 22879382: 1876 edges, 2 circles
# Loaded network 22915745: 5234 edges, 2 circles
# Loaded network 229425177: 4948 edges, 2 circles
# Loaded network 22954430: 2744 edges, 15 circles
# Loaded network 22958268: 1021 edges, 2 circles
# Loaded network 22970486: 613 edges, 4 circles
# Loaded network 229741646: 3114 edges, 20 circles
# Loaded network 22977196: 2554 edges, 1 circles
# Loaded network 229969377: 644 edges, 2 circles
# Loaded network 230601773: 5156 edges, 27 circles
# Loaded network 230880104: 3537 edges, 4 circles
# Loaded network 232006900: 1811 edges, 4 circles
# Loaded network 232706326: 3865 edges, 3 circles
# Loaded network 23334169: 2689 edges, 2 circles
# Loaded network 233598791: 5465 edges, 18 circles
# Loaded network 234169190: 3931 edges, 5 circles
# Loaded network 23469247: 413 edges, 2 circles
# Loaded network 23503181: 1824 edges, 2 circles
# Loaded network 235219400: 1950 edges, 3 circles
# Loaded network 2363991: 4462 edges, 9 circles
# Loaded network 237019614: 774 edges, 3 circles
# Loaded network 237049769: 602 edges, 4 circles
# Loaded network 23742633: 6483 edges, 2 circles
# Loaded network 23759573: 1548 edges, 3 circles
# Loaded network 237845487: 255 edges, 16 circles
# Loaded network 23790454: 1252 edges, 7 circles
# Loaded network 238264600: 1145 edges, 4 circles
# Loaded network 23889102: 345 edges, 2 circles
# Loaded network 239141315: 3268 edges, 11 circles
# Loaded network 239434259: 2318 edges, 3 circles
# Loaded network 240740059: 4282 edges, 2 circles
# Loaded network 24117694: 9630 edges, 1 circles
# Loaded network 241635675: 82 edges, 2 circles
# Loaded network 242013901: 3658 edges, 2 circles
# Loaded network 242024994: 5034 edges, 2 circles
# Loaded network 242073660: 2539 edges, 0 circles
# Loaded network 242479442: 4212 edges, 5 circles
# Loaded network 243267948: 1458 edges, 3 circles
# Loaded network 24479656: 7379 edges, 3 circles
# Loaded network 24541192: 1988 edges, 2 circles
# Loaded network 24542441: 1702 edges, 2 circles
# Loaded network 245639401: 2739 edges, 2 circles
# Loaded network 24636631: 544 edges, 9 circles
# Loaded network 24815332: 4747 edges, 11 circles
# Loaded network 248224845: 3896 edges, 9 circles
# Loaded network 248523038: 698 edges, 1 circles
# Loaded network 248883350: 9042 edges, 2 circles
# Loaded network 248916246: 4882 edges, 4 circles
# Loaded network 24903302: 909 edges, 2 circles
# Loaded network 24907197: 280 edges, 5 circles
# Loaded network 249829509: 2075 edges, 2 circles
# Loaded network 249831237: 249 edges, 2 circles
# Loaded network 250340951: 1783 edges, 2 circles
# Loaded network 250447400: 5098 edges, 1 circles
# Loaded network 250900294: 1491 edges, 4 circles
# Loaded network 25179170: 327 edges, 3 circles
# Loaded network 252415267: 3928 edges, 2 circles
# Loaded network 253360762: 1807 edges, 3 circles
# Loaded network 25344777: 653 edges, 6 circles
# Loaded network 253751053: 928 edges, 6 circles
# Loaded network 253863144: 523 edges, 1 circles
# Loaded network 254883790: 1854 edges, 3 circles
# Loaded network 255790981: 6996 edges, 6 circles
# Loaded network 25649234: 4173 edges, 4 circles
# Loaded network 256497288: 17930 edges, 4 circles
# Loaded network 25650268: 190 edges, 2 circles
# Loaded network 25755158: 1701 edges, 2 circles
# Loaded network 2576401: 1198 edges, 1 circles
# Loaded network 258145892: 1668 edges, 1 circles
# Loaded network 258447233: 950 edges, 2 circles
# Loaded network 2589521: 3417 edges, 6 circles
# Loaded network 258955239: 57 edges, 0 circles
# Loaded network 259288589: 4440 edges, 2 circles
# Loaded network 259365099: 122 edges, 0 circles
# Loaded network 259884200: 675 edges, 4 circles
# Loaded network 26083291: 1955 edges, 2 circles
# Loaded network 26103051: 1378 edges, 2 circles
# Loaded network 261973875: 946 edges, 2 circles
# Loaded network 262310943: 73 edges, 1 circles
# Loaded network 26234692: 307 edges, 2 circles
# Loaded network 26286713: 869 edges, 1 circles
# Loaded network 263224927: 2096 edges, 2 circles
# Loaded network 26335321: 627 edges, 2 circles
# Loaded network 26346966: 1928 edges, 3 circles
# Loaded network 265077741: 2881 edges, 5 circles
# Loaded network 26585095: 614 edges, 13 circles
# Loaded network 26604704: 821 edges, 1 circles
# Loaded network 266464616: 2038 edges, 2 circles
# Loaded network 267383914: 3423 edges, 0 circles
# Loaded network 268425888: 1523 edges, 1 circles
# Loaded network 269485905: 1941 edges, 8 circles
# Loaded network 269559495: 894 edges, 3 circles
# Loaded network 26961048: 2879 edges, 2 circles
# Loaded network 275686563: 1839 edges, 2 circles
# Loaded network 27595997: 303 edges, 2 circles
# Loaded network 276128869: 2140 edges, 3 circles
# Loaded network 276843589: 232 edges, 1 circles
# Loaded network 278181157: 5968 edges, 21 circles
# Loaded network 278311152: 2261 edges, 2 circles
# Loaded network 27853708: 1480 edges, 5 circles
# Loaded network 279854450: 443 edges, 2 circles
# Loaded network 280329780: 1833 edges, 100 circles
# Loaded network 28205087: 1376 edges, 2 circles
# Loaded network 283732062: 5374 edges, 8 circles
# Loaded network 2841151: 1391 edges, 9 circles
# Loaded network 28490110: 4864 edges, 10 circles
# Loaded network 285287229: 4034 edges, 8 circles
# Loaded network 28628055: 1484 edges, 2 circles
# Loaded network 287519521: 201 edges, 7 circles
# Loaded network 2890961: 554 edges, 3 circles
# Loaded network 289738351: 2530 edges, 6 circles
# Loaded network 290092792: 3784 edges, 5 circles
# Loaded network 29016037: 3186 edges, 4 circles
# Loaded network 29034979: 553 edges, 2 circles
# Loaded network 291403100: 787 edges, 2 circles
# Loaded network 292560337: 2812 edges, 1 circles
# Loaded network 29357507: 496 edges, 5 circles
# Loaded network 29514951: 1684 edges, 7 circles
# Loaded network 296218728: 1051 edges, 2 circles
# Loaded network 297985585: 552 edges, 2 circles
# Loaded network 298038575: 2477 edges, 3 circles
# Loaded network 30031265: 1543 edges, 7 circles
# Loaded network 300842571: 5801 edges, 4 circles
# Loaded network 30096240: 653 edges, 1 circles
# Loaded network 301297627: 5686 edges, 5 circles
# Loaded network 30207757: 5502 edges, 7 circles
# Loaded network 30310904: 1083 edges, 2 circles
# Loaded network 30313925: 4031 edges, 4 circles
# Loaded network 30345417: 2603 edges, 3 circles
# Loaded network 303886358: 3008 edges, 2 circles
# Loaded network 30393917: 862 edges, 2 circles
# Loaded network 306445007: 8180 edges, 2 circles
# Loaded network 307458983: 9938 edges, 42 circles
# Loaded network 307478701: 126 edges, 0 circles
# Loaded network 308220010: 1089 edges, 2 circles
# Loaded network 30824363: 868 edges, 1 circles
# Loaded network 309096216: 1307 edges, 2 circles
# Loaded network 30970675: 467 edges, 6 circles
# Loaded network 311227912: 276 edges, 0 circles
# Loaded network 31153819: 1948 edges, 9 circles
# Loaded network 31179985: 578 edges, 4 circles
# Loaded network 312284236: 3553 edges, 3 circles
# Loaded network 31246395: 3510 edges, 4 circles
# Loaded network 312805417: 3928 edges, 4 circles
# Loaded network 31313454: 461 edges, 2 circles
# Loaded network 31317273: 2231 edges, 3 circles
# Loaded network 313359626: 1874 edges, 0 circles
# Loaded network 314038032: 1321 edges, 4 circles
# Loaded network 314316607: 15957 edges, 3 circles
# Loaded network 31457243: 303 edges, 3 circles
# Loaded network 31464977: 156 edges, 1 circles
# Loaded network 31477674: 4191 edges, 1 circles
# Loaded network 315418321: 487 edges, 1 circles
# Loaded network 31610343: 3432 edges, 9 circles
# Loaded network 31631020: 1518 edges, 4 circles
# Loaded network 317313520: 4204 edges, 3 circles
# Loaded network 318760490: 1123 edges, 2 circles
# Loaded network 31949053: 2880 edges, 5 circles
# Loaded network 320527944: 162 edges, 2 circles
# Loaded network 321620987: 558 edges, 3 circles
# Loaded network 321652589: 733 edges, 3 circles
# Loaded network 32289713: 372 edges, 3 circles
# Loaded network 324201646: 238 edges, 17 circles
# Loaded network 3245291: 2373 edges, 5 circles
# Loaded network 324544865: 2939 edges, 7 circles
# Loaded network 3253671: 3942 edges, 2 circles
# Loaded network 32547856: 2569 edges, 2 circles
# Loaded network 32574761: 556 edges, 3 circles
# Loaded network 326259198: 2511 edges, 6 circles
# Loaded network 33060624: 196 edges, 2 circles
# Loaded network 33080832: 366 edges, 1 circles
# Loaded network 33097148: 2502 edges, 1 circles
# Loaded network 333021748: 2634 edges, 23 circles
# Loaded network 3338681: 331 edges, 2 circles
# Loaded network 333881828: 95 edges, 2 circles
# Loaded network 333966373: 1404 edges, 3 circles
# Loaded network 33511585: 3200 edges, 3 circles
# Loaded network 33612973: 4089 edges, 3 circles
# Loaded network 33617320: 2400 edges, 2 circles
# Loaded network 336463060: 4035 edges, 2 circles
# Loaded network 33794839: 71 edges, 2 circles
# Loaded network 338017544: 3925 edges, 3 circles
# Loaded network 33806113: 885 edges, 3 circles
# Loaded network 33868543: 857 edges, 2 circles
# Loaded network 34242979: 4470 edges, 9 circles
# Loaded network 34416153: 3062 edges, 9 circles
# Loaded network 344966590: 2626 edges, 3 circles
# Loaded network 345569115: 792 edges, 2 circles
# Loaded network 34805698: 47 edges, 3 circles
# Loaded network 348851602: 3068 edges, 2 circles
# Loaded network 35012277: 2839 edges, 2 circles
# Loaded network 35012599: 3248 edges, 6 circles
# Loaded network 351092905: 5806 edges, 4 circles
# Loaded network 35166642: 622 edges, 2 circles
# Loaded network 353767514: 1982 edges, 8 circles
# Loaded network 35432497: 1631 edges, 0 circles
# Loaded network 355823615: 463 edges, 1 circles
# Loaded network 356897757: 52 edges, 3 circles
# Loaded network 356963: 705 edges, 11 circles
# Loaded network 35726059: 7799 edges, 3 circles
# Loaded network 358845982: 888 edges, 2 circles
# Loaded network 35926608: 5554 edges, 6 circles
# Loaded network 359791673: 625 edges, 6 circles
# Loaded network 360025190: 1065 edges, 4 circles
# Loaded network 360210947: 1211 edges, 3 circles
# Loaded network 364664695: 460 edges, 2 circles
# Loaded network 36475508: 3167 edges, 17 circles
# Loaded network 36544954: 402 edges, 2 circles
# Loaded network 36618690: 2761 edges, 1 circles
# Loaded network 36629388: 7053 edges, 1 circles
# Loaded network 368018677: 438 edges, 1 circles
# Loaded network 36836787: 2189 edges, 3 circles
# Loaded network 36953510: 795 edges, 0 circles
# Loaded network 37103386: 5914 edges, 3 circles
# Loaded network 37112942: 719 edges, 2 circles
# Loaded network 37170886: 4372 edges, 4 circles
# Loaded network 37201612: 1394 edges, 3 circles
# Loaded network 372765570: 1037 edges, 2 circles
# Loaded network 374007416: 638 edges, 11 circles
# Loaded network 37723441: 1705 edges, 3 circles
# Loaded network 377662213: 801 edges, 4 circles
# Loaded network 37792861: 1119 edges, 2 circles
# Loaded network 378494343: 1227 edges, 2 circles
# Loaded network 37899473: 940 edges, 2 circles
# Loaded network 37977732: 703 edges, 10 circles
# Loaded network 37992666: 1463 edges, 3 circles
# Loaded network 38108292: 2977 edges, 3 circles
# Loaded network 381688396: 418 edges, 2 circles
# Loaded network 382110320: 4481 edges, 1 circles
# Loaded network 384685422: 6563 edges, 5 circles
# Loaded network 384761809: 2068 edges, 2 circles
# Loaded network 38703025: 1217 edges, 3 circles
# Loaded network 38761811: 2846 edges, 2 circles
# Loaded network 39070445: 654 edges, 4 circles
# Loaded network 39157827: 406 edges, 3 circles
# Loaded network 39322973: 2451 edges, 3 circles
# Loaded network 396721965: 21 edges, 2 circles
# Loaded network 39695043: 139 edges, 2 circles
# Loaded network 397688944: 690 edges, 1 circles
# Loaded network 398994309: 2015 edges, 2 circles
# Loaded network 40022380: 321 edges, 1 circles
# Loaded network 400867704: 340 edges, 2 circles
# Loaded network 402970625: 736 edges, 3 circles
# Loaded network 40564708: 522 edges, 1 circles
# Loaded network 40580577: 3421 edges, 2 circles
# Loaded network 40705032: 392 edges, 0 circles
# Loaded network 407769660: 2145 edges, 4 circles
# Loaded network 40777046: 39 edges, 3 circles
# Loaded network 40813518: 3310 edges, 2 circles
# Loaded network 40818894: 861 edges, 1 circles
# Loaded network 40981798: 2948 edges, 2 circles
# Loaded network 414334713: 1269 edges, 4 circles
# Loaded network 41945050: 1155 edges, 3 circles
# Loaded network 42098834: 448 edges, 3 circles
# Loaded network 423567032: 2567 edges, 2 circles
# Loaded network 42522911: 299 edges, 1 circles
# Loaded network 4258591: 837 edges, 2 circles
# Loaded network 42676302: 561 edges, 3 circles
# Loaded network 428333: 1242 edges, 4 circles
# Loaded network 42912024: 1752 edges, 2 circles
# Loaded network 43003845: 3592 edges, 2 circles
# Loaded network 430313102: 1646 edges, 2 circles
# Loaded network 43194901: 313 edges, 7 circles
# Loaded network 434433610: 4002 edges, 20 circles
# Loaded network 43540843: 2805 edges, 7 circles
# Loaded network 437300342: 5421 edges, 7 circles
# Loaded network 43858661: 37 edges, 3 circles
# Loaded network 4387041: 620 edges, 4 circles
# Loaded network 441252694: 583 edges, 3 circles
# Loaded network 44130462: 3698 edges, 5 circles
# Loaded network 44257374: 2499 edges, 3 circles
# Loaded network 44394333: 475 edges, 2 circles
# Loaded network 44524106: 1072 edges, 1 circles
# Loaded network 44666348: 6255 edges, 2 circles
# Loaded network 45145944: 199 edges, 0 circles
# Loaded network 45310286: 3351 edges, 8 circles
# Loaded network 45333725: 371 edges, 4 circles
# Loaded network 45690012: 4985 edges, 8 circles
# Loaded network 45753733: 4413 edges, 2 circles
# Loaded network 45857296: 367 edges, 18 circles
# Loaded network 46160500: 3225 edges, 5 circles
# Loaded network 46533358: 1904 edges, 2 circles
# Loaded network 47359057: 3133 edges, 2 circles
# Loaded network 47673661: 1225 edges, 2 circles
# Loaded network 477094958: 442 edges, 2 circles
# Loaded network 47854857: 3863 edges, 7 circles
# Loaded network 48132655: 2366 edges, 3 circles
# Loaded network 48436259: 818 edges, 2 circles
# Loaded network 484991854: 326 edges, 2 circles
# Loaded network 48730516: 341 edges, 7 circles
# Loaded network 49098552: 164 edges, 3 circles
# Loaded network 49253437: 4179 edges, 2 circles
# Loaded network 493138720: 820 edges, 14 circles
# Loaded network 49414491: 294 edges, 4 circles
# Loaded network 494538543: 637 edges, 4 circles
# Loaded network 49536244: 1400 edges, 10 circles
# Loaded network 50145896: 1115 edges, 3 circles
# Loaded network 50189671: 531 edges, 5 circles
# Loaded network 51694885: 3609 edges, 7 circles
# Loaded network 51775432: 488 edges, 1 circles
# Loaded network 521489919: 150 edges, 2 circles
# Loaded network 52330027: 6493 edges, 2 circles
# Loaded network 52405864: 4135 edges, 2 circles
# Loaded network 52442002: 1091 edges, 2 circles
# Loaded network 52498113: 2948 edges, 2 circles
# Loaded network 52772629: 2069 edges, 1 circles
# Loaded network 528575851: 1659 edges, 20 circles
# Loaded network 53235381: 275 edges, 1 circles
# Loaded network 532617990: 74 edges, 2 circles
# Loaded network 53685618: 1942 edges, 2 circles
# Loaded network 54107218: 3655 edges, 4 circles
# Loaded network 54168315: 371 edges, 4 circles
# Loaded network 54178513: 1027 edges, 4 circles
# Loaded network 54226675: 1493 edges, 2 circles
# Loaded network 54331626: 250 edges, 2 circles
# Loaded network 54460963: 1028 edges, 2 circles
# Loaded network 54695584: 1209 edges, 7 circles
# Loaded network 5471892: 1918 edges, 8 circles
# Loaded network 54791004: 985 edges, 3 circles
# Loaded network 549089429: 125 edges, 1 circles
# Loaded network 55019615: 7218 edges, 2 circles
# Loaded network 5506012: 760 edges, 3 circles
# Loaded network 5539522: 2408 edges, 2 circles
# Loaded network 55928029: 731 edges, 0 circles
# Loaded network 5747502: 721 edges, 4 circles
# Loaded network 5773532: 1090 edges, 2 circles
# Loaded network 5774432: 3407 edges, 2 circles
# Loaded network 57828817: 4243 edges, 2 circles
# Loaded network 58427526: 9105 edges, 2 circles
# Loaded network 58525541: 126 edges, 0 circles
# Loaded network 58641627: 1910 edges, 2 circles
# Loaded network 5868402: 2072 edges, 2 circles
# Loaded network 58930815: 2813 edges, 4 circles
# Loaded network 59359628: 967 edges, 1 circles
# Loaded network 59588845: 2539 edges, 5 circles
# Loaded network 59676554: 850 edges, 2 circles
# Loaded network 6018292: 463 edges, 3 circles
# Loaded network 61086747: 4253 edges, 2 circles
# Loaded network 61158706: 420 edges, 3 circles
# Loaded network 612473: 1195 edges, 10 circles
# Loaded network 61311054: 2159 edges, 8 circles
# Loaded network 613313: 968 edges, 2 circles
# Loaded network 6165372: 2055 edges, 2 circles
# Loaded network 61781462: 147 edges, 3 circles
# Loaded network 61890555: 152 edges, 3 circles
# Loaded network 623623: 521 edges, 2 circles
# Loaded network 6253282: 536 edges, 2 circles
# Loaded network 62609430: 787 edges, 1 circles
# Loaded network 62740714: 521 edges, 2 circles
# Loaded network 62759402: 2376 edges, 2 circles
# Loaded network 6297852: 3257 edges, 4 circles
# Loaded network 62985251: 4422 edges, 2 circles
# Loaded network 629863: 1099 edges, 7 circles
# Loaded network 63084853: 993 edges, 4 circles
# Loaded network 63207451: 8922 edges, 2 circles
# Loaded network 6351572: 3085 edges, 1 circles
# Loaded network 63787760: 5093 edges, 3 circles
# Loaded network 6408382: 3379 edges, 3 circles
# Loaded network 64253854: 81 edges, 3 circles
# Loaded network 64441390: 1028 edges, 5 circles
# Loaded network 64496469: 400 edges, 2 circles
# Loaded network 64508047: 1174 edges, 7 circles
# Loaded network 64619842: 2795 edges, 2 circles
# Loaded network 64931560: 4560 edges, 3 circles
# Loaded network 65185224: 858 edges, 4 circles
# Loaded network 65357070: 1009 edges, 0 circles
# Loaded network 65360846: 357 edges, 5 circles
# Loaded network 66100530: 126 edges, 2 circles
# Loaded network 66136244: 3069 edges, 2 circles
# Loaded network 66185823: 1666 edges, 4 circles
# Loaded network 6650612: 115 edges, 2 circles
# Loaded network 66761133: 4705 edges, 6 circles
# Loaded network 66804457: 285 edges, 3 circles
# Loaded network 66841215: 545 edges, 4 circles
# Loaded network 67378554: 2055 edges, 3 circles
# Loaded network 68179571: 241 edges, 2 circles
# Loaded network 68257605: 1844 edges, 2 circles
# Loaded network 68480165: 207 edges, 1 circles
# Loaded network 68732646: 1582 edges, 4 circles
# Loaded network 69049114: 3883 edges, 6 circles
# Loaded network 69193714: 2126 edges, 3 circles
# Loaded network 69548480: 4164 edges, 3 circles
# Loaded network 69624952: 734 edges, 3 circles
# Loaded network 70123665: 1026 edges, 2 circles
# Loaded network 70160230: 1910 edges, 3 circles
# Loaded network 70492333: 987 edges, 4 circles
# Loaded network 70620846: 672 edges, 2 circles
# Loaded network 7098022: 851 edges, 1 circles
# Loaded network 71091272: 97 edges, 1 circles
# Loaded network 7144422: 127 edges, 1 circles
# Loaded network 72339761: 3447 edges, 3 circles
# Loaded network 73024519: 3965 edges, 5 circles
# Loaded network 73025843: 2640 edges, 9 circles
# Loaded network 73298877: 134 edges, 2 circles
# Loaded network 73443014: 1092 edges, 2 circles
# Loaded network 734493: 54 edges, 0 circles
# Loaded network 73707412: 4127 edges, 2 circles
# Loaded network 73738774: 883 edges, 5 circles
# Loaded network 742143: 747 edges, 3 circles
# Loaded network 7424642: 661 edges, 6 circles
# Loaded network 74264908: 512 edges, 3 circles
# Loaded network 745823: 6320 edges, 12 circles
# Loaded network 74651704: 7157 edges, 7 circles
# Loaded network 7517222: 4992 edges, 17 circles
# Loaded network 75321229: 533 edges, 2 circles
# Loaded network 75343905: 585 edges, 4 circles
# Loaded network 75370828: 4160 edges, 5 circles
# Loaded network 759679: 782 edges, 2 circles
# Loaded network 7668362: 3516 edges, 2 circles
# Loaded network 7670202: 1978 edges, 4 circles
# Loaded network 7682452: 6195 edges, 13 circles
# Loaded network 77404713: 2305 edges, 3 circles
# Loaded network 77843323: 1462 edges, 8 circles
# Loaded network 778446: 3537 edges, 10 circles
# Loaded network 779715: 4200 edges, 12 circles
# Loaded network 78138151: 893 edges, 2 circles
# Loaded network 78391198: 610 edges, 2 circles
# Loaded network 7861312: 4740 edges, 6 circles
# Loaded network 7875912: 5753 edges, 4 circles
# Loaded network 78813: 2861 edges, 2 circles
# Loaded network 7888452: 1244 edges, 9 circles
# Loaded network 7890392: 4489 edges, 2 circles
# Loaded network 789071: 1128 edges, 2 circles
# Loaded network 78944566: 5254 edges, 3 circles
# Loaded network 790205: 5498 edges, 1 circles
# Loaded network 79797834: 4089 edges, 12 circles
# Loaded network 80297299: 1434 edges, 6 circles
# Loaded network 80317145: 2011 edges, 2 circles
# Loaded network 80479756: 582 edges, 1 circles
# Loaded network 80660928: 2808 edges, 7 circles
# Loaded network 80681990: 3664 edges, 9 circles
# Loaded network 80688804: 639 edges, 4 circles
# Loaded network 8079892: 3153 edges, 1 circles
# Loaded network 809864: 3737 edges, 2 circles
# Loaded network 81938351: 580 edges, 2 circles
# Loaded network 819800: 2400 edges, 10 circles
# Loaded network 82726142: 1305 edges, 4 circles
# Loaded network 83048001: 822 edges, 3 circles
# Loaded network 83285096: 2916 edges, 1 circles
# Loaded network 83478370: 1061 edges, 1 circles
# Loaded network 83883736: 1067 edges, 3 circles
# Loaded network 84114921: 309 edges, 3 circles
# Loaded network 84473837: 2090 edges, 5 circles
# Loaded network 85432934: 3106 edges, 2 circles
# Loaded network 85716069: 5061 edges, 5 circles
# Loaded network 86560711: 4473 edges, 2 circles
# Loaded network 86664924: 441 edges, 0 circles
# Loaded network 86775971: 5811 edges, 1 circles
# Loaded network 86799233: 553 edges, 2 circles
# Loaded network 87004822: 671 edges, 5 circles
# Loaded network 87114066: 2050 edges, 6 circles
# Loaded network 87525002: 3294 edges, 2 circles
# Loaded network 8768832: 868 edges, 1 circles
# Loaded network 87771546: 1123 edges, 2 circles
# Loaded network 87798068: 3867 edges, 2 circles
# Loaded network 88456842: 5364 edges, 3 circles
# Loaded network 88639412: 3018 edges, 4 circles
# Loaded network 88931752: 204 edges, 7 circles
# Loaded network 89032548: 3658 edges, 2 circles
# Loaded network 8914942: 5791 edges, 2 circles
# Loaded network 89826562: 9715 edges, 2 circles
# Loaded network 90072587: 1630 edges, 2 circles
# Loaded network 90880254: 44 edges, 2 circles
# Loaded network 90998968: 2058 edges, 3 circles
# Loaded network 91067832: 3724 edges, 3 circles
# Loaded network 9215692: 2317 edges, 3 circles
# Loaded network 9254272: 1779 edges, 1 circles
# Loaded network 926981: 5620 edges, 1 circles
# Loaded network 92715435: 899 edges, 1 circles
# Loaded network 9298152: 2398 edges, 7 circles
# Loaded network 93006320: 4120 edges, 8 circles
# Loaded network 93787797: 3183 edges, 4 circles
# Loaded network 93906304: 1676 edges, 6 circles
# Loaded network 93998005: 1435 edges, 3 circles
# Loaded network 94147192: 488 edges, 12 circles
# Loaded network 94480069: 5347 edges, 2 circles
# Loaded network 9460682: 2003 edges, 3 circles
# Loaded network 94915681: 1544 edges, 1 circles
# Loaded network 9524062: 2856 edges, 6 circles
# Loaded network 96483973: 7289 edges, 2 circles
# Loaded network 96545499: 38 edges, 2 circles
# Loaded network 96843721: 2626 edges, 4 circles
# Loaded network 96907622: 6246 edges, 2 circles
# Loaded network 98345808: 139 edges, 0 circles
# Loaded network 9855382: 67 edges, 1 circles
# Loaded network 98633794: 2354 edges, 5 circles
# Loaded network 98801140: 5 edges, 2 circles
# Loaded network 99841247: 619 edges, 57 circles

# %% [markdown]
# ## 2. Build Graphs and Extract Basic Stats
#
# Construct NetworkX graphs and compute basic statistics; save as CSVs.

# %%
# Build graphs
def build_ego_graph(node_id, network_data):
    G = nx.DiGraph()
    edges = network_data.get('edges', pd.DataFrame(columns=['source','target']))
    if not edges.empty:
        G.add_edges_from(edges.values)
    G.add_node(node_id)
    neighbors = set()
    if not edges.empty:
        neighbors = set(edges['source'].tolist()) | set(edges['target'].tolist())
    for n in neighbors:
        G.add_edge(node_id, n)
    return G

graphs = {}
for node_id, network_data in all_networks.items():
    graphs[node_id] = build_ego_graph(node_id, network_data)

# Compute basic stats
def compute_basic_stats(G):
    stats = {
        'num_nodes': G.number_of_nodes(),
        'num_edges': G.number_of_edges(),
        'density': nx.density(G),
        'is_connected': nx.is_weakly_connected(G) if G.number_of_nodes()>0 else False,
    }
    try:
        stats['num_scc'] = nx.number_strongly_connected_components(G)
        stats['num_wcc'] = nx.number_weakly_connected_components(G)
    except Exception:
        stats['num_scc'] = 0
        stats['num_wcc'] = 0
    return stats

network_stats = {nid: compute_basic_stats(G) for nid, G in graphs.items()}
stats_df = pd.DataFrame(network_stats).T
stats_df.index.name = 'network_id'
print('Basic Network Statistics (first rows):')
display(stats_df.head())
# Save
stats_df.to_csv(summary_dir / 'basic_stats.csv')
# Out:
# Basic Network Statistics (first rows):
#            num_nodes num_edges   density is_connected num_scc num_wcc
# network_id
# 100318079        221      8574  0.176347         True       4       1
# 10146102          96      1046  0.114693         True      12       1
# 101859065         24       231  0.418478         True       3       1
# 101903164         15        65  0.309524         True       4       1
# 102765423         85      1154  0.161625         True       9       1

# %% [markdown]
# ## 3. Degree Statistics (tables)
#
# Compute degree statistics for each network and save results.

# %%
# Compute degree statistics
def compute_degree_stats(G):
    in_degrees = [d for _, d in G.in_degree()]
    out_degrees = [d for _, d in G.out_degree()]
    if len(in_degrees)==0: in_degrees=[0]
    if len(out_degrees)==0: out_degrees=[0]
    stats = {
        'mean_in_degree': float(np.mean(in_degrees)),
        'median_in_degree': float(np.median(in_degrees)),
        'max_in_degree': int(np.max(in_degrees)),
        'std_in_degree': float(np.std(in_degrees)),
        'mean_out_degree': float(np.mean(out_degrees)),
        'median_out_degree': float(np.median(out_degrees)),
        'max_out_degree': int(np.max(out_degrees)),
        'std_out_degree': float(np.std(out_degrees)),
    }
    return stats, in_degrees, out_degrees

degree_stats = {}
degree_distributions = {}
for nid, G in graphs.items():
    st, ind, outd = compute_degree_stats(G)
    degree_stats[nid] = st
    degree_distributions[nid] = {'in': ind, 'out': outd}
degree_stats_df = pd.DataFrame(degree_stats).T
degree_stats_df.index.name = 'network_id'
print('Degree statistics (first rows):')
display(degree_stats_df.head())
degree_stats_df.to_csv(summary_dir / 'degree_stats.csv')
# Out:
# Degree statistics (first rows):
#             mean_in_degree  median_in_degree  max_in_degree  std_in_degree  \
# network_id
# 100318079        38.796380              27.0          175.0      34.071381
# 10146102         10.895833              10.0           36.0       7.297944
# 101859065         9.625000               8.0           18.0       4.599026
# 101903164         4.333333               5.0            9.0       2.599145
# 102765423        13.576471               9.0           59.0      12.353972
#
#             mean_out_degree  median_out_degree  max_out_degree  std_out_degree
# network_id
# 100318079         38.796380               32.0           220.0       32.664885
# 10146102          10.895833                9.0            95.0       11.489560
# 101859065          9.625000                8.0            23.0        5.483403
# 101903164          4.333333                3.0            14.0        3.438346
# 102765423         13.576471                9.0            84.0       13.205504

# %% [markdown]
# ## 4. Clustering Coefficients (tables)
#
# Compute clustering stats and save results.

# %%
def compute_clustering_stats(G):
    G_undirected = G.to_undirected()
    if G_undirected.number_of_nodes() == 0:
        return {
            'avg_clustering': 0.0, 'transitivity': 0.0, 'max_clustering': 0.0, 'min_clustering': 0.0, 'std_clustering': 0.0
        }, []
    try:
        avg_clustering = nx.average_clustering(G_undirected)
    except Exception:
        avg_clustering = 0.0
    try:
        transitivity = nx.transitivity(G_undirected)
    except Exception:
        transitivity = 0.0
    clustering_coeffs = list(nx.clustering(G_undirected).values())
    stats = {
        'avg_clustering': float(avg_clustering),
        'transitivity': float(transitivity),
        'max_clustering': float(np.max(clustering_coeffs)) if clustering_coeffs else 0.0,
        'min_clustering': float(np.min(clustering_coeffs)) if clustering_coeffs else 0.0,
        'std_clustering': float(np.std(clustering_coeffs)) if clustering_coeffs else 0.0
    }
    return stats, clustering_coeffs

clustering_stats = {}
clustering_distributions = {}
for nid, G in graphs.items():
    st, coeffs = compute_clustering_stats(G)
    clustering_stats[nid] = st
    clustering_distributions[nid] = coeffs
clustering_df = pd.DataFrame(clustering_stats).T
clustering_df.index.name = 'network_id'
print('Clustering stats (first rows):')
display(clustering_df.head())
clustering_df.to_csv(summary_dir / 'clustering_stats.csv')
# Out:
# Clustering stats (first rows):
#             avg_clustering  transitivity  max_clustering  min_clustering  \
# network_id
# 100318079         0.616636      0.560765             1.0        0.247862
# 10146102          0.583678      0.378358             1.0        0.142889
# 101859065         0.788856      0.707054             1.0        0.569170
# 101903164         0.805493      0.595174             1.0        0.395604
# 102765423         0.624577      0.498334             1.0        0.223752
#
#             std_clustering
# network_id
# 100318079         0.144841
# 10146102          0.176623
# 101859065         0.133865
# 101903164         0.211975
# 102765423         0.163678

# %% [markdown]
# ## 5. Comprehensive Table
#
# Combine all metrics into a single comprehensive dataframe and save to CSV. Prefer tables over multiple dashboards.

# %%
comprehensive_df = stats_df.copy()
comprehensive_df = comprehensive_df.join(degree_stats_df, how='left')
comprehensive_df = comprehensive_df.join(clustering_df, how='left')
comprehensive_df['avg_degree'] = (comprehensive_df['mean_in_degree'] + comprehensive_df['mean_out_degree']) / 2

# Ensure index dtype
comprehensive_df.index = comprehensive_df.index.map(str)
print('Comprehensive metrics (first rows):')
display(comprehensive_df.head())
comprehensive_df.to_csv(summary_dir / 'comprehensive_metrics.csv')
# Out:
# Comprehensive metrics (first rows):
#            num_nodes num_edges   density is_connected num_scc num_wcc  \
# network_id
# 100318079        221      8574  0.176347         True       4       1
# 10146102          96      1046  0.114693         True      12       1
# 101859065         24       231  0.418478         True       3       1
# 101903164         15        65  0.309524         True       4       1
# 102765423         85      1154  0.161625         True       9       1
#
#             mean_in_degree  median_in_degree  max_in_degree  std_in_degree  \
# network_id
# 100318079        38.796380              27.0          175.0      34.071381
# 10146102         10.895833              10.0           36.0       7.297944
# 101859065         9.625000               8.0           18.0       4.599026
# 101903164         4.333333               5.0            9.0       2.599145
# 102765423        13.576471               9.0           59.0      12.353972
#
#             mean_out_degree  median_out_degree  max_out_degree  \
# network_id
# 100318079         38.796380               32.0           220.0
# 10146102          10.895833                9.0            95.0
# 101859065          9.625000                8.0            23.0
# 101903164          4.333333                3.0            14.0
# 102765423         13.576471                9.0            84.0
#
#             std_out_degree  avg_clustering  transitivity  max_clustering  \
# network_id
# 100318079        32.664885        0.616636      0.560765             1.0
# 10146102         11.489560        0.583678      0.378358             1.0
# 101859065         5.483403        0.788856      0.707054             1.0
# 101903164         3.438346        0.805493      0.595174             1.0
# 102765423        13.205504        0.624577      0.498334             1.0
#
#             min_clustering  std_clustering  avg_degree
# network_id
# 100318079         0.247862        0.144841   38.796380
# 10146102          0.142889        0.176623   10.895833
# 101859065         0.569170        0.133865    9.625000
# 101903164         0.395604        0.211975    4.333333
# 102765423         0.223752        0.163678   13.576471

# %% [markdown]
# ## 6. Outlier Detection (tables)
#
# Identify outliers via z-score and save the results.

# %%
from scipy import stats
def identify_outliers(df, columns, threshold=1.5):
    outliers = {}
    for col in columns:
        if col not in df.columns:
            continue
        col_vals = df[col].astype(float).values
        z_scores = np.abs((col_vals - np.nanmean(col_vals)) / (np.nanstd(col_vals) if np.nanstd(col_vals)!=0 else 1e-8))
        mask = z_scores > threshold
        if mask.any():
            nets = df.index[mask].tolist()
            vals = df.loc[nets, col].tolist()
            zs = z_scores[mask].tolist()
            outliers[col] = {'networks': nets, 'values': vals, 'z_scores': zs}
    return outliers

metrics_to_check = ['num_nodes', 'num_edges', 'density', 'avg_degree', 'avg_clustering', 'transitivity']
outliers = identify_outliers(comprehensive_df, metrics_to_check, threshold=1.5)
print('Outliers summary:')
out_rows = []
for metric, data in outliers.items():
    for net, val, z in zip(data['networks'], data['values'], data['z_scores']):
        out_rows.append({'metric': metric, 'network': net, 'value': val, 'z_score': z})
outliers_df = pd.DataFrame(out_rows)
display(outliers_df.head())
outliers_df.to_csv(summary_dir / 'outliers_flat.csv', index=False)
import json
with open(summary_dir / 'outliers.json', 'w') as f:
    json.dump(outliers, f, indent=2)
# Out:
# Outliers summary:
#       metric    network  value   z_score
# 0  num_nodes  101859065   24.0  1.687679
# 1  num_nodes  101903164   15.0  1.827339
# 2  num_nodes  104324908   14.0  1.842857
# 3  num_nodes  105398724   22.0  1.718714
# 4  num_nodes  107172099   24.0  1.687679

# %% [markdown]
# ## 7. Clustering (tables) and minimal plotting
#
# Perform clustering, save assignments and cluster summary. Optionally produce one heatmap (correlation).

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

clustering_features = [c for c in ['num_nodes','num_edges','density','avg_degree','avg_clustering','transitivity'] if c in comprehensive_df.columns]
if len(comprehensive_df) >= 2 and len(clustering_features) >= 2:
    scaler = StandardScaler()
    X = comprehensive_df[clustering_features].astype(float).fillna(0)
    X_scaled = scaler.fit_transform(X)
    optimal_k = min(3, max(2, len(comprehensive_df)//2))
    kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(X_scaled)
    comprehensive_df['cluster'] = labels
    comprehensive_df.to_csv(summary_dir / 'comprehensive_with_clusters.csv')
    # cluster summary table
    cluster_summary = comprehensive_df.groupby('cluster')[clustering_features].agg(['mean','std','count'])
    display(cluster_summary)
    cluster_summary.to_csv(summary_dir / 'cluster_summary.csv')
    # save PCA coords
    pca = PCA(n_components=2)
    pca_coords = pca.fit_transform(X_scaled)
    pca_df = pd.DataFrame(pca_coords, index=comprehensive_df.index, columns=['PC1','PC2'])
    pca_df.to_csv(summary_dir / 'pca_coords.csv')
else:
    comprehensive_df['cluster'] = 0
    comprehensive_df.to_csv(summary_dir / 'comprehensive_with_clusters.csv')
    cluster_summary = comprehensive_df.groupby('cluster')[clustering_features].agg(['mean','std','count'])
    cluster_summary.to_csv(summary_dir / 'cluster_summary.csv')
    display(cluster_summary.head())
# Out:
#           num_nodes                     num_edges                     \
#                mean        std count         mean          std count
# cluster
# 0        124.030992  52.109308   484  1360.427686   832.779489   484
# 1         56.413043  31.673075   184  1150.168478  1224.357389   184
# 2        192.662295  33.527493   305   5065.67541  2018.644884   305
#
#           density                 avg_degree                 avg_clustering  \
#              mean       std count       mean       std count           mean
# cluster
# 0        0.093115  0.039204   484  10.251880  3.986632   484       0.634833
# 1         0.31709  0.121365   184  15.997337  9.645128   184       0.758261
# 2        0.142873  0.055929   305  26.380026  9.152414   305       0.607463
#
#                         transitivity
#               std count         mean       std count
# cluster
# 0        0.063395   484     0.365091  0.098708   484
# 1        0.062439   184     0.651811  0.101639   184
# 2        0.051441   305     0.476164  0.078913   305

# %% [markdown]
# ## 8. Typical vs Unusual Networks (tables)
#
# Classify networks by distance from mean and save lists and summary tables.

# %%
mean_values = comprehensive_df[clustering_features].mean() if len(clustering_features)>0 else pd.Series()
std_values = comprehensive_df[clustering_features].std().replace(0, 1e-8) if len(clustering_features)>0 else pd.Series()
distances = []
for idx in comprehensive_df.index:
    if len(clustering_features)==0:
        distances.append(0.0)
        continue
    network_values = comprehensive_df.loc[idx, clustering_features]
    z_scores = (network_values - mean_values) / std_values
    distance = np.sqrt((z_scores.fillna(0) ** 2).sum())
    distances.append(distance)
comprehensive_df['distance_from_mean'] = distances
comprehensive_df['is_typical'] = comprehensive_df['distance_from_mean'] < np.nanmedian(comprehensive_df['distance_from_mean'])
typical_networks = comprehensive_df[comprehensive_df['is_typical']].index.tolist()
unusual_networks = comprehensive_df[~comprehensive_df['is_typical']].index.tolist()
pd.Series(typical_networks).to_csv(summary_dir / 'typical_networks.csv', index=False, header=False)
pd.Series(unusual_networks).to_csv(summary_dir / 'unusual_networks.csv', index=False, header=False)
print(f'Typical networks ({len(typical_networks)}): {typical_networks}')
print(f'Unusual networks ({len(unusual_networks)}): {unusual_networks}')
display(comprehensive_df[[*clustering_features, 'distance_from_mean', 'is_typical']].head())
comprehensive_df.to_csv(summary_dir / 'comprehensive_final.csv')
# Out:
# Typical networks (486): ['10146102', '102765423', '103865085', '103991905', '1046661', '104991493', '105150583', '105918870', '107418464', '107512718', '10798802', '11027262', '110755733', '111045742', '11136132', '111374622', '112628165', '113196940', '11348722', '114115460', '114885421', '115221382', '116798290', '11681802', '117029850', '117671022', '117800618', '117809922', '11784842', '12069912', '120971873', '12152402', '121569946', '121685268', '123684709', '12415722', '124296976', '125098615', '12570812', '12771872', '127912925', '129093262', '13179562', '13212502', '132519763', '13275962', '13317162', '134208594', '13460312', '135605269', '13649212', '137046366', '13747362', '13872872', '14045302', '14058831', '14077024', '14120253', '14147754', '141488457', '14191254', '14203895', '14313005', '143172151', '14332288', '143344048', '14365883', '143661263', '14371740', '14372763', '14404235', '144211337', '14521330', '14528221', '14550962', '14618160', '14755105', '14791232', '14807093', '14838506', '14840869', '14843763', '14848513', '148519842', '14917050', '14922225', '14936377', '14957252', '14984096', '15070932', '15099384', '151175266', '15129912', '15164892', '152062126', '152388029', '152435436', '15331855', '15347317', '15419775', '15473958', '15477120', '1548841', '155689319', '155976326', '15647676', '15665127', '15706128', '15741636', '158414847', '15849055', '15864197', '159588456', '159629146', '15977848', '16027078', '160839015', '1608991', '16193542', '16279105', '16285517', '16305227', '163374693', '163491360', '163629705', '16421962', '16465113', '165580617', '165598423', '16591188', '16606585', '16610683', '16613128', '166252256', '16652550', '16734718', '16790036', '16809036', '16824073', '16834201', '168537920', '16878507', '170167167', '17022544', '171202083', '17137927', '17384099', '17561785', '17602896', '17636894', '17714569', '17723880', '17787399', '17822419', '179065820', '179138862', '18068719', '18069824', '18226205', '18252740', '18338485', '18374320', '183786731', '184391654', '184755890', '18486243', '18486881', '18534908', '18571832', '186354564', '18718580', '18731347', '18734310', '18788502', '18836167', '18846990', '18895362', '189111957', '189253902', '18957524', '189592841', '18996905', '190138306', '19064433', '19136295', '191896931', '191916463', '191924526', '19208450', '19213083', '19380307', '19492215', '19563357', '19658936', '19668026', '196926575', '19725644', '197577781', '197602850', '198628427', '199483163', '200494218', '202346485', '2029971', '20319646', '203868162', '204145356', '20436059', '20446839', '20495756', '20561154', '20758393', '20950208', '20999409', '21061498', '21094279', '21132431', '211933541', '212642904', '21318259', '21339164', '21363077', '21391704', '21420959', '21437537', '21578499', '21648994', '219365298', '22106463', '22121627', '222090651', '225302763', '2257971', '22745706', '227650565', '227785045', '228270980', '22879382', '22958268', '22970486', '229741646', '230601773', '232006900', '232706326', '23334169', '23503181', '235219400', '2363991', '237019614', '237049769', '23759573', '23790454', '239141315', '240740059', '242073660', '242479442', '24541192', '24542441', '245639401', '24636631', '248224845', '248523038', '24903302', '249829509', '250900294', '25179170', '252415267', '253751053', '253863144', '25755158', '258145892', '2589521', '259288589', '26083291', '261973875', '26286713', '263224927', '26335321', '26585095', '266464616', '267383914', '268425888', '269485905', '269559495', '26961048', '276128869', '28205087', '2841151', '28490110', '285287229', '28628055', '289738351', '29016037', '29034979', '291403100', '29357507', '296218728', '298038575', '30031265', '30310904', '30313925', '30345417', '303886358', '308220010', '309096216', '30970675', '31179985', '312284236', '31313454', '31317273', '314038032', '31477674', '31610343', '31631020', '317313520', '318760490', '31949053', '321620987', '324544865', '3253671', '32547856', ' ...
# Unusual networks (487): ['100318079', '101859065', '101903164', '102903198', '103431502', '104324908', '104615636', '105398724', '107172099', '107511013', '107516840', '108159877', '108205076', '10985532', '110536616', '11348282', '113509970', '115911638', '116388817', '116808228', '11828432', '11928542', '119897041', '120157205', '120459837', '120679977', '121202578', '121258930', '122216533', '123287376', '1239671', '124474025', '126067398', '1271901', '128135741', '12831', '129984134', '130734452', '13274152', '133663120', '134943586', '135397331', '135704499', '135895585', '136341512', '1367531', '137527381', '13809612', '13811562', '13837812', '14060856', '14120151', '14129601', '141341662', '14134942', '14150874', '14199378', '1422311', '14256927', '14327149', '14338082', '14353392', '1435461', '14372486', '14422788', '14426892', '144723379', '14505838', '14555534', '145573135', '14630490', '14677919', '14711172', '14719129', '14794851', '14827526', '14836915', '14849487', '14869783', '14893314', '15001424', '15012486', '150402542', '15053535', '151246522', '151495845', '15208246', '15292446', '153245741', '15329577', '15335809', '15420650', '15445811', '154648125', '154701532', '15481789', '15507297', '15527013', '15533771', '155661154', '15589323', '15642031', '157488488', '15797184', '158419434', '15859268', '158874150', '15924858', '15938936', '15944663', '15947217', '15989218', '160237722', '16105942', '16183380', '16212913', '16234125', '16247469', '16263665', '16297193', '163674521', '16437633', '16476088', '16505296', '165786567', '16616109', '166214735', '16674149', '16685316', '16726878', '167901620', '168224294', '16840742', '16869298', '169216507', '169780164', '16987303', '17045060', '170729553', '17111909', '17135931', '171536167', '17396702', '17403755', '17421011', '174285878', '17503591', '175529494', '175553601', '17600223', '17627996', '176310143', '17658786', '176589903', '176872879', '176936249', '1775731', '17767841', '17770689', '17797990', '17866414', '17874544', '17912917', '17918629', '17922109', '180540375', '18119683', '18135029', '18191231', '18201401', '182609394', '18270489', '18278524', '184594566', '18470775', '18472735', '18481292', '18483115', '18496986', '185512077', '18558612', '18594420', '18630326', '18665800', '18681592', '18687625', '18690700', '186909156', '187569483', '187744415', '187773078', '188102842', '18886852', '18917716', '18923866', '18951737', '189875309', '18988524', '190696559', '19110632', '19225156', '19283723', '19299909', '19454519', '195475105', '19760380', '197731654', '197903282', '198327282', '198370650', '198941747', '19898730', '199039532', '19933035', '19948202', '19976791', '200214366', '20060293', '20119746', '20179628', '202114894', '202195505', '20347014', '204646586', '20689206', '206923844', '207594668', '207936757', '2097571', '21028234', '21077642', '211547273', '21222922', '212718048', '21337501', '21364753', '21415375', '215328630', '215824411', '216843160', '21731779', '21735280', '217796457', '21816783', '22252971', '224581852', '22751884', '22863638', '22915745', '229425177', '22954430', '22977196', '229969377', '230880104', '233598791', '234169190', '23469247', '23742633', '237845487', '238264600', '23889102', '239434259', '24117694', '241635675', '242013901', '242024994', '243267948', '24479656', '24815332', '248883350', '248916246', '24907197', '249831237', '250340951', '250447400', '253360762', '25344777', '254883790', '255790981', '25649234', '256497288', '25650268', '2576401', '258447233', '258955239', '259365099', '259884200', '26103051', '262310943', '26234692', '26346966', '265077741', '26604704', '275686563', '27595997', '276843589', '278181157', '278311152', '27853708', '279854450', '280329780', '283732062', '287519521', '2890961', '290092792', '292560337', '29514951', '297985585', '300842571', '30096240', '301297627', '30207757', '30393917', '306445007', '307458983', '307478701', '30824363', '311227912', '31153819', '31246395', '31 ...
#            num_nodes num_edges   density  avg_degree  avg_clustering  \
# network_id
# 100318079        221      8574  0.176347   38.796380        0.616636
# 10146102          96      1046  0.114693   10.895833        0.583678
# 101859065         24       231  0.418478    9.625000        0.788856
# 101903164         15        65  0.309524    4.333333        0.805493
# 102765423         85      1154  0.161625   13.576471        0.624577
#
#             transitivity  distance_from_mean  is_typical
# network_id
# 100318079       0.560765            3.883064       False
# 10146102        0.378358            1.452719        True
# 101859065       0.707054            4.091499       False
# 101903164       0.595174            3.589911       False
# 102765423       0.498334            1.088896        True

# %%
# --- Select best networks based on analysis ---
import numpy as np

metrics = [c for c in ['num_nodes','num_edges','density','avg_degree','avg_clustering','transitivity'] if c in comprehensive_df.columns]
rank_df = comprehensive_df.copy()

if len(metrics) > 0:
    z = (rank_df[metrics].astype(float).fillna(0) - rank_df[metrics].mean()) / rank_df[metrics].std().replace(0, 1e-8)
    for m in metrics:
        rank_df[f'z_{m}'] = z[m]
    # composite score: sum of absolute z-scores (higher => more atypical)
    rank_df['composite_score'] = z.abs().sum(axis=1)
else:
    rank_df['composite_score'] = 0

# ensure distance_from_mean exists
if 'distance_from_mean' not in rank_df.columns:
    if len(metrics) > 0:
        rank_df['distance_from_mean'] = np.sqrt((z.fillna(0) ** 2).sum(axis=1))
    else:
        rank_df['distance_from_mean'] = 0

# selection helpers
def pick_representative(df):
    return df['distance_from_mean'].idxmin() if len(df) > 0 else None

def pick_most_atypical(df, topk=3):
    return df.sort_values('composite_score', ascending=False).head(topk).index.tolist()

def pick_by_metric(df, metric, topk=3):
    return df.sort_values(metric, ascending=False).head(topk).index.tolist() if metric in df.columns else []

# picks
representative_net = pick_representative(rank_df)
atypical_top3 = pick_most_atypical(rank_df, topk=3)
top_by_nodes = pick_by_metric(rank_df, 'num_nodes', topk=3)

# Save selections to CSVs
if representative_net is not None:
    pd.Series([representative_net]).to_csv(summary_dir / 'representative_network.csv', index=False, header=False)
else:
    pd.Series([]).to_csv(summary_dir / 'representative_network.csv', index=False, header=False)

pd.Series(atypical_top3).to_csv(summary_dir / 'atypical_top3.csv', index=False, header=False)
pd.Series(top_by_nodes).to_csv(summary_dir / 'top_by_nodes.csv', index=False, header=False)

# Save ranking table (include composite and distance + z-scores)
cols_to_save = ['composite_score', 'distance_from_mean'] + [f'z_{m}' for m in metrics]
rank_df[cols_to_save].to_csv(summary_dir / 'network_rankings.csv')

# Print results and small preview
print('Representative network:', representative_net)
print('Top 3 atypical networks:', atypical_top3)
print('Top 3 by node count:', top_by_nodes)

if representative_net in graphs:
    best_graph = graphs[representative_net]
    print(f"Representative graph summary — nodes: {best_graph.number_of_nodes()}, edges: {best_graph.number_of_edges()}")

# Show top atypical by composite score
display(rank_df.sort_values('composite_score', ascending=False).head())
# Out:
# Representative network: 197602850
# Top 3 atypical networks: ['256497288', '734493', '16297193']
# Top 3 by node count: ['170729553', '134943586', '24117694']
# Representative graph summary — nodes: 135, edges: 2340
#            num_nodes num_edges   density is_connected num_scc num_wcc  \
# network_id
# 256497288        214     18143   0.39803         True       9       1
# 734493            10        63       0.7         True       4       1
# 16297193          14       124  0.681319         True       2       1
# 1435461          130      8166  0.486941         True       5       1
# 314316607        236     16192  0.291958         True       2       1
#
#             mean_in_degree  median_in_degree  max_in_degree  std_in_degree  \
# network_id
# 256497288        84.780374              86.0          167.0      42.685039
# 734493            6.300000               7.0            8.0       2.147091
# 16297193          8.857143              10.0           12.0       3.356383
# 1435461          62.815385              63.0           99.0      16.874553
# 314316607        68.610169              60.0          228.0      45.426423
#
#             ...  cluster  distance_from_mean  is_typical  z_num_nodes  \
# network_id  ...
# 256497288   ...        2           10.495348       False     1.260059
# 734493      ...        1            7.728051       False    -1.903949
# 16297193    ...        1            7.346494       False     -1.84191
# 1435461     ...        1            7.071881       False    -0.042768
# 314316607   ...        2            8.358842       False     1.601276
#
#             z_num_edges  z_density  z_avg_degree  z_avg_clustering  \
# network_id
# 256497288      7.033285   2.310339      6.780685          1.821427
# 734493        -1.086428   5.135271     -1.000842          3.875984
# 16297193      -1.059033   4.960507     -0.747295          3.613231
# 1435461        2.552623   3.142102      4.602801          2.467729
# 314316607      6.157093   1.318037      5.177368          0.140135
#
#             z_transitivity  composite_score
# network_id
# 256497288         2.112943        21.318738
# 734493             3.53857        16.541045
# 16297193          3.352055        15.574031
# 1435461           2.519032        15.327054
# 314316607         0.913434        15.307343
#
# [5 rows x 30 columns]

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /Users/hugues/anaconda3/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: torchvision in /Users/hugues/anaconda3/lib/python3.13/site-packages (0.24.1)
# Requirement already satisfied: torchaudio in /Users/hugues/anaconda3/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: filelock in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: numpy in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/hugues/anaconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)

# %%
# --- Prepare selected graph and run a small GCN (if torch available) ---
import numpy as np

if 'representative_net' not in globals() or representative_net is None:
    print('No representative network selected. Run the previous selection cell first.')
else:
    rep = representative_net
    print('Preparing graph for GNN:', rep)
    Gsel = graphs[rep].to_undirected()
    nodes = list(Gsel.nodes())
    n = len(nodes)
    if n == 0:
        print('Graph is empty.')
    else:
        idx = {node: i for i, node in enumerate(nodes)}
        A = nx.to_numpy_array(Gsel, nodelist=nodes)
        # Node features: degree and clustering (and ego feature if available)
        deg = np.array([Gsel.degree(n) for n in nodes], dtype=float)
        clust = np.array([nx.clustering(Gsel, n) for n in nodes], dtype=float)
        X = np.vstack([deg, clust]).T
        # Normalize features
        X = (X - X.mean(axis=0)) / (X.std(axis=0) + 1e-8)

        # Synthetic labels: bin degrees into 3 classes (low/med/high)
        try:
            import pandas as pd
            labels = pd.qcut(deg, q=3, labels=False, duplicates='drop').astype(int).values
            num_classes = int(labels.max() + 1)
        except Exception:
            labels = (deg > np.median(deg)).astype(int)
            num_classes = max(2, int(labels.max() + 1))

        # Save prepared data
        prep_df = pd.DataFrame(X, index=nodes, columns=['deg_z','clust_z'])
        prep_df['label'] = labels
        prep_df.to_csv(summary_dir / f'prepared_{rep}_nodes.csv')
        print(f'Prepared node features and labels saved to: {summary_dir}/prepared_{rep}_nodes.csv')

        # Try to run a small GCN using PyTorch (no torch -> show install instructions)
        try:
            import torch
            import torch.nn as nn
            import torch.nn.functional as F
            import torch.optim as optim

            device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
            print('Using device:', device)

            # Build normalized adjacency
            A_tilde = A + np.eye(n)
            D = np.diag(A_tilde.sum(axis=1))
            D_inv_sqrt = np.linalg.inv(np.sqrt(D))
            A_norm = D_inv_sqrt @ A_tilde @ D_inv_sqrt
            A_norm = torch.tensor(A_norm, dtype=torch.float32, device=device)
            X_t = torch.tensor(X, dtype=torch.float32, device=device)
            y = torch.tensor(labels, dtype=torch.long, device=device)

            # Simple train/val/test split
            rng = np.random.default_rng(42)
            perm = rng.permutation(n)
            n_train = max(1, int(0.6 * n))
            n_val = max(1, int(0.2 * n))
            idx_train = perm[:n_train]
            idx_val = perm[n_train:n_train + n_val]
            idx_test = perm[n_train + n_val:]

            class SimpleGCN(nn.Module):
                def __init__(self, in_feats, hid_feats, out_feats):
                    super().__init__()
                    self.w1 = nn.Parameter(torch.randn(in_feats, hid_feats) / np.sqrt(in_feats))
                    self.w2 = nn.Parameter(torch.randn(hid_feats, out_feats) / np.sqrt(hid_feats))

                def forward(self, X, A_norm):
                    H = A_norm @ (X @ self.w1)
                    H = F.relu(H)
                    Z = A_norm @ (H @ self.w2)
                    return Z

            model = SimpleGCN(in_feats=X.shape[1], hid_feats=16, out_feats=num_classes).to(device)
            opt = optim.Adam(model.parameters(), lr=0.01, weight_decay=5e-4)
            loss_fn = nn.CrossEntropyLoss()

            # Training loop
            best_val = 1e9
            best_state = None
            for epoch in range(1, 201):
                model.train()
                logits = model(X_t, A_norm)
                loss = loss_fn(logits[idx_train], y[idx_train])
                opt.zero_grad()
                loss.backward()
                opt.step()

                model.eval()
                with torch.no_grad():
                    logits = model(X_t, A_norm)
                    val_loss = loss_fn(logits[idx_val], y[idx_val]).item() if len(idx_val)>0 else 0.0
                    pred = logits.argmax(dim=1)
                    train_acc = (pred[idx_train] == y[idx_train]).float().mean().item()
                    val_acc = (pred[idx_val] == y[idx_val]).float().mean().item() if len(idx_val)>0 else 0.0
                if epoch % 50 == 0 or epoch == 1:
                    print(f'Epoch {epoch:03d}  loss={loss.item():.4f}  train_acc={train_acc:.3f}  val_acc={val_acc:.3f}')
                if val_loss < best_val:
                    best_val = val_loss
                    best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}

            # Evaluate on test set
            if best_state is not None:
                model.load_state_dict(best_state)
            model.eval()
            with torch.no_grad():
                logits = model(X_t, A_norm)
                pred = logits.argmax(dim=1)
                test_acc = (pred[idx_test] == y[idx_test]).float().mean().item() if len(idx_test)>0 else 0.0
            print(f'Test accuracy: {test_acc:.3f}')

            # Save node embeddings (hidden layer activations)
            with torch.no_grad():
                H = F.relu(A_norm @ (X_t @ model.w1))
                emb = H.cpu().numpy()
            emb_df = pd.DataFrame(emb, index=nodes)
            emb_df.to_csv(summary_dir / f'{rep}_node_embeddings.csv')
            print('Saved node embeddings to:', summary_dir / f'{rep}_node_embeddings.csv')

        except Exception as e:
            print('PyTorch not available or error during training:', e)
            print('To run the GCN, install PyTorch (and optional GPU support). Example:')
            print('\n  pip install torch torchvision torchaudio\n')
            print('Then re-run this cell.')
# Out:
# Preparing graph for GNN: 197602850
# Prepared node features and labels saved to: twitter_ego/twitter/summary_tables/prepared_197602850_nodes.csv
# Using device: cpu
# Epoch 001  loss=0.8126  train_acc=0.556  val_acc=0.407
# Epoch 050  loss=0.4135  train_acc=0.840  val_acc=1.000
# Epoch 100  loss=0.3010  train_acc=0.840  val_acc=0.926
# Epoch 150  loss=0.2548  train_acc=0.877  val_acc=0.926
# Epoch 200  loss=0.2274  train_acc=0.877  val_acc=0.926
# Test accuracy: 0.778
# Saved node embeddings to: twitter_ego/twitter/summary_tables/197602850_node_embeddings.csv

# %% [markdown]
# ## 9. Optional: Correlation Heatmap (single plot)
#
# Produce one heatmap image saved to summary_dir if desired.

# %%
metrics_cols = [c for c in ['num_nodes','num_edges','density','avg_degree','avg_clustering','transitivity','mean_in_degree','mean_out_degree'] if c in comprehensive_df.columns]
if len(metrics_cols) >= 2:
    corr = comprehensive_df[metrics_cols].corr()
    plt.figure(figsize=(10,8))
    sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', center=0, square=True, linewidths=0.8, cbar_kws={'shrink':0.8})
    plt.title('Correlation Matrix of Network Metrics')
    plt.tight_layout()
    plt.savefig(summary_dir / 'correlation_heatmap.png', dpi=150, bbox_inches='tight')
    plt.close()
    print('Saved correlation_heatmap.png')
else:
    print('Not enough metrics for heatmap')
# Out:
# Saved correlation_heatmap.png

# %%
# Save and display the representative graph image
from IPython.display import display, Image
rep = globals().get('representative_net', None)
if rep is None:
    print('Aucun graphe représentatif sélectionné. Exécutez la cellule de sélection dabord.')
else:
    if 'graphs' not in globals() or rep not in graphs:
        print(f'Graphe {rep} introuvable dans la variable graphs.')
    else:
        Grep = graphs[rep]
        out_path = summary_dir / f'{rep}_graph.png'
        plt.figure(figsize=(8,8))
        pos = nx.spring_layout(Grep, seed=42)
        nx.draw(Grep, pos=pos, node_size=50, with_labels=False, edge_color='#888888')
        plt.title(f'Graphe représentatif: {rep}')
        plt.tight_layout()
        plt.savefig(out_path, dpi=150, bbox_inches='tight')
        plt.close()
        print('Graphe sauvegardé sous :', out_path)
        try:
            display(Image(filename=str(out_path)))
        except Exception:
            print('Impossible dafficher limage dans cet environnement; le fichier est sauvegardé.')
# Out:
# Graphe sauvegardé sous : twitter_ego/twitter/summary_tables/197602850_graph.png

# %% [markdown]
# ## Final Summary
#
# Print concise report and paths to saved CSVs.

# %%
print('='*80)
print('FINAL SUMMARY REPORT')
print('='*80)
print(f"Total ego networks analyzed: {len(ego_network_ids)}")
print(f"Summary CSVs and outputs saved to: {summary_dir}")
print('Saved files:')
for p in sorted(summary_dir.iterdir()):
    print(' -', p.name)
print('='*80)
print('Analysis complete')
# Out:
# ================================================================================
# FINAL SUMMARY REPORT
# ================================================================================
# Total ego networks analyzed: 973
# Summary CSVs and outputs saved to: twitter_ego/twitter/summary_tables
# Saved files:
#  - 197602850_graph.png
#  - 197602850_node_embeddings.csv
#  - atypical_top3.csv
#  - basic_stats.csv
#  - cluster_summary.csv
#  - clustering_stats.csv
#  - comprehensive_final.csv
#  - comprehensive_metrics.csv
#  - comprehensive_with_clusters.csv
#  - correlation_heatmap.png
#  - degree_stats.csv
#  - network_rankings.csv
#  - outliers.json
#  - outliers_flat.csv
#  - pca_coords.csv
#  - prepared_197602850_nodes.csv
#  - representative_network.csv
#  - top_by_nodes.csv
#  - typical_networks.csv
#  - unusual_networks.csv
# ================================================================================
# Analysis complete

# %%
from IPython.display import display, Markdown

rep = globals().get('representative_net', None)

if rep is None:
    display(Markdown("**Aucun graphe représentatif sélectionné. Exécutez la cellule de sélection d'abord.**"))
else:
    display(Markdown(f"## Résumé du graphe sélectionné : **{rep}**"))

    # Basic graph description
    if 'graphs' in globals() and rep in graphs:
        Gsel = graphs[rep]
        n_nodes = Gsel.number_of_nodes()
        n_edges = Gsel.number_of_edges()
        density = nx.density(Gsel)
        display(Markdown(f"- Nombre de nœuds : **{n_nodes}**"))
        display(Markdown(f"- Nombre d'arêtes : **{n_edges}**"))
        display(Markdown(f"- Densité : **{density:.4f}**"))
        if 'clustering_df' in globals() and rep in clustering_df.index:
            display(Markdown(f"- Clustering moyen : **{clustering_df.loc[rep,'avg_clustering']:.4f}**"))

    # Show prepared node features if available
    prep_path = summary_dir / f'prepared_{rep}_nodes.csv'
    if prep_path.exists():
        display(Markdown('### Extrait des features préparées (nœuds)'))
        try:
            dfp = pd.read_csv(prep_path, index_col=0)
            display(dfp.head())
        except Exception as e:
            display(Markdown(f'Erreur lecture {prep_path}: {e}'))
    else:
        display(Markdown('Fichier préparé des nœuds non trouvé.'))

    # Show embeddings if available
    emb_path = summary_dir / f'{rep}_node_embeddings.csv'
    if emb_path.exists():
        display(Markdown('### Extrait des embeddings de nœuds'))
        try:
            emdf = pd.read_csv(emb_path, index_col=0)
            display(emdf.head())
        except Exception as e:
            display(Markdown(f'Erreur lecture {emb_path}: {e}'))
    else:
        display(Markdown('Embeddings non trouvés (le GCN n\'a peut-être pas été exécuté).'))

    # GNN results summary
    if 'test_acc' in globals():
        display(Markdown('### Résultats GNN'))
        display(Markdown(f'- Accuracy (test) : **{test_acc:.3f}**'))
    else:
        display(Markdown('### Résultats GNN\n- Aucun résultat de test disponible (GCN non exécuté ou erreur).'))

    # Interpretation and next steps
    explanation = (
        """
**Interprétation (automatique)**

- Le graphe représentatif est choisi comme le réseau le plus proche de la moyenne des métriques (distance_from_mean minimale), il sert de cas typique.
- Le GCN a été entraîné sur des étiquettes synthétiques (bins de degré). Une accuracy élevée indique que la structure locale (degré, clustering) est discriminante pour cette tâche synthétique.
- Les embeddings de nœuds (si présents) peuvent être utilisés pour : clustering, réduction de dimension, visualisation ou tâches en aval.

**Prochaines étapes suggérées**

1. Vérifier/affiner les labels (utiliser des vraies étiquettes si disponibles).
2. Ajouter d'autres features nodales (attributs .feat ou egofeat) pour améliorer la prédiction.
3. Évaluer la robustesse (cross-validation, répétitions) et comparer plusieurs graphes sélectionnés (ex. atypiques vs représentatif).
4. Visualiser embeddings (UMAP / t-SNE) et examiner la séparation des classes.

"""
    )
    display(Markdown(explanation))
# Out:
# ## Résumé du graphe sélectionné : **197602850**
# - Nombre de nœuds : **135**
# - Nombre d'arêtes : **2340**
# - Densité : **0.1294**
# - Clustering moyen : **0.6372**
# ### Extrait des features préparées (nœuds)
#               deg_z   clust_z  label
# 17576144   1.281719 -0.382918      1
# 49273095   1.643819 -0.705498      1
# 6804822    0.350605  0.165129      1
# 22863357   0.247148  0.209596      1
# 143950772  0.091962 -1.301619      1
# ### Extrait des embeddings de nœuds
#                   0         1         2         3         4         5    6  \
# 17576144   0.307849  0.000000  0.737272  0.017922  0.790784  0.648461  0.0
# 49273095   0.365645  0.000000  0.712916  0.020355  0.761771  0.713693  0.0
# 6804822    0.437087  0.000000  0.768056  0.023849  0.818854  0.823922  0.0
# 22863357   0.459668  0.000000  0.735470  0.024668  0.782365  0.841399  0.0
# 143950772  0.174880  0.037851  0.000000  0.006827  0.000000  0.165058  0.0
#
#                   7         8         9   10   11        12        13   14  \
# 17576144   0.652136  0.459253  0.941219  0.0  0.0  0.000000  0.000000  0.0
# 49273095   0.659569  0.476504  0.910918  0.0  0.0  0.000000  0.000000  0.0
# 6804822    0.728985  0.533949  0.981875  0.0  0.0  0.000000  0.000000  0.0
# 22863357   0.715589  0.530913  0.940696  0.0  0.0  0.000000  0.000000  0.0
# 143950772  0.000000  0.012749  0.000000  0.0  0.0  0.020729  0.484172  0.0
#
#             15
# 17576144   0.0
# 49273095   0.0
# 6804822    0.0
# 22863357   0.0
# 143950772  0.0
# ### Résultats GNN
# - Accuracy (test) : **0.778**
# **Interprétation (automatique)**
#
# - Le graphe représentatif est choisi comme le réseau le plus proche de la moyenne des métriques (distance_from_mean minimale), il sert de cas typique.
# - Le GCN a été entraîné sur des étiquettes synthétiques (bins de degré). Une accuracy élevée indique que la structure locale (degré, clustering) est discriminante pour cette tâche synthétique.
# - Les embeddings de nœuds (si présents) peuvent être utilisés pour : clustering, réduction de dimension, visualisation ou tâches en aval.
#
# **Prochaines étapes suggérées**
#
# 1. Vérifier/affiner les labels (utiliser des vraies étiquettes si disponibles).
# 2. Ajouter d'autres features nodales (attributs .feat ou egofeat) pour améliorer la prédiction.
# 3. Évaluer la robustesse (cross-validation, répétitions) et comparer plusieurs graphes sélectionnés (ex. atypiques vs représentatif).
# 4. Visualiser embeddings (UMAP / t-SNE) et examiner la séparation des classes.
